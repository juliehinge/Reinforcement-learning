# %% [markdown]
# # Task
#
# We will use the SAC algorithm to train the **walker** environment.
#
# You can implement it yourself or use the Stablebaselines3 version.
#
# Walker environment consists of a structure of legs and the agent's actions can move the joints. The goal is to make the structure able to walk.
#
# You can see more about the actions, observations and rewards [here](https://gymnasium.farama.org/environments/mujoco/walker2d/)
#
# ![Walker Image](https://gymnasium.farama.org/_images/walker2d.gif)

# %%
# Import necessary libraries
import gymnasium as gym
from stable_baselines3 import SAC
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.results_plotter import load_results, ts2xy
import imageio
import numpy as np
import matplotlib.pyplot as plt
import os

# Create a folder to save logs
log_dir = "tmp/"
os.makedirs(log_dir, exist_ok=True)

# Create the Humanoid environment and wrap it in a Monitor wrapper

env = gym.make('Walker2d-v4')

env = Monitor(env, log_dir)

# Set up the hyperparameters
sac_hyperparams = {
    'learning_rate': 1e-4,
    'buffer_size': 200000,
    'batch_size': 128,
    'gamma': 0.997, #0.98,
    'tau': 0.01,
    'train_freq': (1, 'step'), # 1
    'gradient_steps': 4,
    'policy_kwargs': dict(net_arch=[400, 300]),
    'ent_coef': 'auto'  # Using automatic entropy tuning
}

# Initialize the SAC model with the environment and custom hyperparameters
model = SAC("MlpPolicy", env, verbose=1, **sac_hyperparams)

# Train the model
model.learn(total_timesteps=1000000, log_interval=10)

# Save the trained model
model.save("sac_humanoid")

# Function to plot training progress
def plot_results(log_folder):
    x, y = ts2xy(load_results(log_folder), 'timesteps')
    plt.figure(figsize=(10, 5))
    plt.plot(x, y)
    plt.xlabel('Timesteps')
    plt.ylabel('Rewards')
    plt.title('Training Progress')
    plt.show()

# Plot the training progress
plot_results(log_dir)

# Delete the model to demonstrate loading
del model

# Load the saved model
model = SAC.load("sac_humanoid")

# Reset the environment
obs, info = env.reset()

# Create a list to store frames
frames = []

# Run the model in the environment
for _ in range(1000):
    action, _states = model.predict(obs, deterministic=True)
    obs, reward, terminated, truncated, info = env.step(action)
    
    # Capture the current frame
    frame = env.render()
    frames.append(frame)
    
    if terminated or truncated:
        obs, info = env.reset()

# Save frames as a video
video_filename = 'humanoid_sac.mp4'
imageio.mimsave(video_filename, [np.array(frame) for frame in frames], fps=30)
# Out:
# Using cpu device
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 29.2     |
# |    ep_rew_mean     | 9.18     |
# | time/              |          |
# |    episodes        | 10       |
# |    fps             | 59       |
# |    time_elapsed    | 4        |
# |    total_timesteps | 292      |
# | train/             |          |
# |    actor_loss      | -31.3    |
# |    critic_loss     | 5.38     |
# |    ent_coef        | 0.929    |
# |    ent_coef_loss   | -0.638   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 764      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 108      |
# |    ep_rew_mean     | 54       |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 43       |
# |    time_elapsed    | 49       |
# |    total_timesteps | 2164     |
# | train/             |          |
# |    actor_loss      | -172     |
# |    critic_loss     | 103      |
# |    ent_coef        | 0.467    |
# |    ent_coef_loss   | -3.12    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 8252     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 168      |
# |    ep_rew_mean     | 87.7     |
# | time/              |          |
# |    episodes        | 30       |
# |    fps             | 39       |
# |    time_elapsed    | 127      |
# |    total_timesteps | 5037     |
# | train/             |          |
# |    actor_loss      | -331     |
# |    critic_loss     | 173      |
# |    ent_coef        | 0.254    |
# |    ent_coef_loss   | 0.182    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 19744    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 168      |
# |    ep_rew_mean     | 95.6     |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 38       |
# |    time_elapsed    | 174      |
# |    total_timesteps | 6737     |
# | train/             |          |
# |    actor_loss      | -345     |
# |    critic_loss     | 188      |
# |    ent_coef        | 0.259    |
# |    ent_coef_loss   | -0.749   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 26544    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 164      |
# |    ep_rew_mean     | 94.9     |
# | time/              |          |
# |    episodes        | 50       |
# |    fps             | 39       |
# |    time_elapsed    | 210      |
# |    total_timesteps | 8211     |
# | train/             |          |
# |    actor_loss      | -337     |
# |    critic_loss     | 216      |
# |    ent_coef        | 0.235    |
# |    ent_coef_loss   | 0.242    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 32440    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 171      |
# |    ep_rew_mean     | 115      |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 40       |
# |    time_elapsed    | 257      |
# |    total_timesteps | 10286    |
# | train/             |          |
# |    actor_loss      | -290     |
# |    critic_loss     | 185      |
# |    ent_coef        | 0.204    |
# |    ent_coef_loss   | 0.0441   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 40740    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 180      |
# |    ep_rew_mean     | 127      |
# | time/              |          |
# |    episodes        | 70       |
# |    fps             | 40       |
# |    time_elapsed    | 315      |
# |    total_timesteps | 12629    |
# | train/             |          |
# |    actor_loss      | -253     |
# |    critic_loss     | 130      |
# |    ent_coef        | 0.174    |
# |    ent_coef_loss   | -0.185   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 50112    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 187      |
# |    ep_rew_mean     | 143      |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 40       |
# |    time_elapsed    | 369      |
# |    total_timesteps | 14995    |
# | train/             |          |
# |    actor_loss      | -215     |
# |    critic_loss     | 85.9     |
# |    ent_coef        | 0.159    |
# |    ent_coef_loss   | -0.207   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 59576    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 196      |
# |    ep_rew_mean     | 159      |
# | time/              |          |
# |    episodes        | 90       |
# |    fps             | 40       |
# |    time_elapsed    | 431      |
# |    total_timesteps | 17619    |
# | train/             |          |
# |    actor_loss      | -189     |
# |    critic_loss     | 62.9     |
# |    ent_coef        | 0.129    |
# |    ent_coef_loss   | -0.0307  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 70072    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 203      |
# |    ep_rew_mean     | 174      |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 41       |
# |    time_elapsed    | 491      |
# |    total_timesteps | 20271    |
# | train/             |          |
# |    actor_loss      | -171     |
# |    critic_loss     | 36.6     |
# |    ent_coef        | 0.123    |
# |    ent_coef_loss   | -0.448   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 80680    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 231      |
# |    ep_rew_mean     | 204      |
# | time/              |          |
# |    episodes        | 110      |
# |    fps             | 40       |
# |    time_elapsed    | 575      |
# |    total_timesteps | 23392    |
# | train/             |          |
# |    actor_loss      | -153     |
# |    critic_loss     | 50.1     |
# |    ent_coef        | 0.108    |
# |    ent_coef_loss   | 0.218    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 93164    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 233      |
# |    ep_rew_mean     | 227      |
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 40       |
# |    time_elapsed    | 627      |
# |    total_timesteps | 25458    |
# | train/             |          |
# |    actor_loss      | -154     |
# |    critic_loss     | 25.3     |
# |    ent_coef        | 0.0951   |
# |    ent_coef_loss   | -0.334   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 101428   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 233      |
# |    ep_rew_mean     | 250      |
# | time/              |          |
# |    episodes        | 130      |
# |    fps             | 40       |
# |    time_elapsed    | 695      |
# |    total_timesteps | 28341    |
# | train/             |          |
# |    actor_loss      | -150     |
# |    critic_loss     | 20       |
# |    ent_coef        | 0.0874   |
# |    ent_coef_loss   | -1.08    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 112960   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 243      |
# |    ep_rew_mean     | 273      |
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 41       |
# |    time_elapsed    | 756      |
# |    total_timesteps | 31031    |
# | train/             |          |
# |    actor_loss      | -146     |
# |    critic_loss     | 20.4     |
# |    ent_coef        | 0.0814   |
# |    ent_coef_loss   | -0.139   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 123720   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 261      |
# |    ep_rew_mean     | 307      |
# | time/              |          |
# |    episodes        | 150      |
# |    fps             | 41       |
# |    time_elapsed    | 829      |
# |    total_timesteps | 34323    |
# | train/             |          |
# |    actor_loss      | -149     |
# |    critic_loss     | 24.6     |
# |    ent_coef        | 0.0894   |
# |    ent_coef_loss   | -0.053   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 136888   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 286      |
# |    ep_rew_mean     | 338      |
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 41       |
# |    time_elapsed    | 931      |
# |    total_timesteps | 38887    |
# | train/             |          |
# |    actor_loss      | -161     |
# |    critic_loss     | 26.1     |
# |    ent_coef        | 0.0889   |
# |    ent_coef_loss   | -0.31    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 155144   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 301      |
# |    ep_rew_mean     | 363      |
# | time/              |          |
# |    episodes        | 170      |
# |    fps             | 41       |
# |    time_elapsed    | 1018     |
# |    total_timesteps | 42752    |
# | train/             |          |
# |    actor_loss      | -164     |
# |    critic_loss     | 29.9     |
# |    ent_coef        | 0.0936   |
# |    ent_coef_loss   | 0.537    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 170604   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 304      |
# |    ep_rew_mean     | 371      |
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 42       |
# |    time_elapsed    | 1075     |
# |    total_timesteps | 45401    |
# | train/             |          |
# |    actor_loss      | -168     |
# |    critic_loss     | 26.8     |
# |    ent_coef        | 0.0897   |
# |    ent_coef_loss   | -0.472   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 181200   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 299      |
# |    ep_rew_mean     | 372      |
# | time/              |          |
# |    episodes        | 190      |
# |    fps             | 42       |
# |    time_elapsed    | 1118     |
# |    total_timesteps | 47565    |
# | train/             |          |
# |    actor_loss      | -162     |
# |    critic_loss     | 31.8     |
# |    ent_coef        | 0.0883   |
# |    ent_coef_loss   | -0.0697  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 189856   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 307      |
# |    ep_rew_mean     | 382      |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 43       |
# |    time_elapsed    | 1184     |
# |    total_timesteps | 50958    |
# | train/             |          |
# |    actor_loss      | -160     |
# |    critic_loss     | 36.6     |
# |    ent_coef        | 0.0904   |
# |    ent_coef_loss   | -0.0968  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 203428   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 314      |
# |    ep_rew_mean     | 404      |
# | time/              |          |
# |    episodes        | 210      |
# |    fps             | 43       |
# |    time_elapsed    | 1265     |
# |    total_timesteps | 54755    |
# | train/             |          |
# |    actor_loss      | -158     |
# |    critic_loss     | 24       |
# |    ent_coef        | 0.0785   |
# |    ent_coef_loss   | 0.152    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 218616   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 331      |
# |    ep_rew_mean     | 433      |
# | time/              |          |
# |    episodes        | 220      |
# |    fps             | 43       |
# |    time_elapsed    | 1343     |
# |    total_timesteps | 58559    |
# | train/             |          |
# |    actor_loss      | -161     |
# |    critic_loss     | 22.3     |
# |    ent_coef        | 0.0807   |
# |    ent_coef_loss   | -0.141   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 233832   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 337      |
# |    ep_rew_mean     | 451      |
# | time/              |          |
# |    episodes        | 230      |
# |    fps             | 43       |
# |    time_elapsed    | 1414     |
# |    total_timesteps | 62088    |
# | train/             |          |
# |    actor_loss      | -161     |
# |    critic_loss     | 19.8     |
# |    ent_coef        | 0.0761   |
# |    ent_coef_loss   | -0.456   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 247948   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 337      |
# |    ep_rew_mean     | 460      |
# | time/              |          |
# |    episodes        | 240      |
# |    fps             | 43       |
# |    time_elapsed    | 1474     |
# |    total_timesteps | 64755    |
# | train/             |          |
# |    actor_loss      | -167     |
# |    critic_loss     | 17.2     |
# |    ent_coef        | 0.0753   |
# |    ent_coef_loss   | 1.29     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 258616   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 352      |
# |    ep_rew_mean     | 480      |
# | time/              |          |
# |    episodes        | 250      |
# |    fps             | 44       |
# |    time_elapsed    | 1579     |
# |    total_timesteps | 69527    |
# | train/             |          |
# |    actor_loss      | -171     |
# |    critic_loss     | 20.6     |
# |    ent_coef        | 0.0708   |
# |    ent_coef_loss   | 0.361    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 277704   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 347      |
# |    ep_rew_mean     | 476      |
# | time/              |          |
# |    episodes        | 260      |
# |    fps             | 44       |
# |    time_elapsed    | 1668     |
# |    total_timesteps | 73610    |
# | train/             |          |
# |    actor_loss      | -178     |
# |    critic_loss     | 22.7     |
# |    ent_coef        | 0.0731   |
# |    ent_coef_loss   | -0.363   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 294036   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 358      |
# |    ep_rew_mean     | 508      |
# | time/              |          |
# |    episodes        | 270      |
# |    fps             | 44       |
# |    time_elapsed    | 1778     |
# |    total_timesteps | 78529    |
# | train/             |          |
# |    actor_loss      | -181     |
# |    critic_loss     | 23.9     |
# |    ent_coef        | 0.077    |
# |    ent_coef_loss   | -0.487   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 313712   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 378      |
# |    ep_rew_mean     | 535      |
# | time/              |          |
# |    episodes        | 280      |
# |    fps             | 44       |
# |    time_elapsed    | 1881     |
# |    total_timesteps | 83158    |
# | train/             |          |
# |    actor_loss      | -191     |
# |    critic_loss     | 22.4     |
# |    ent_coef        | 0.0759   |
# |    ent_coef_loss   | -0.261   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 332228   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 402      |
# |    ep_rew_mean     | 574      |
# | time/              |          |
# |    episodes        | 290      |
# |    fps             | 44       |
# |    time_elapsed    | 1974     |
# |    total_timesteps | 87783    |
# | train/             |          |
# |    actor_loss      | -191     |
# |    critic_loss     | 22.8     |
# |    ent_coef        | 0.074    |
# |    ent_coef_loss   | 1.33     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 350728   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 438      |
# |    ep_rew_mean     | 624      |
# | time/              |          |
# |    episodes        | 300      |
# |    fps             | 44       |
# |    time_elapsed    | 2123     |
# |    total_timesteps | 94796    |
# | train/             |          |
# |    actor_loss      | -211     |
# |    critic_loss     | 21.9     |
# |    ent_coef        | 0.0723   |
# |    ent_coef_loss   | -0.286   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 378780   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 440      |
# |    ep_rew_mean     | 626      |
# | time/              |          |
# |    episodes        | 310      |
# |    fps             | 44       |
# |    time_elapsed    | 2215     |
# |    total_timesteps | 98791    |
# | train/             |          |
# |    actor_loss      | -213     |
# |    critic_loss     | 21       |
# |    ent_coef        | 0.0677   |
# |    ent_coef_loss   | 0.43     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 394760   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 438      |
# |    ep_rew_mean     | 621      |
# | time/              |          |
# |    episodes        | 320      |
# |    fps             | 44       |
# |    time_elapsed    | 2287     |
# |    total_timesteps | 102358   |
# | train/             |          |
# |    actor_loss      | -213     |
# |    critic_loss     | 23.7     |
# |    ent_coef        | 0.0687   |
# |    ent_coef_loss   | 0.231    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 409028   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 456      |
# |    ep_rew_mean     | 645      |
# | time/              |          |
# |    episodes        | 330      |
# |    fps             | 44       |
# |    time_elapsed    | 2396     |
# |    total_timesteps | 107668   |
# | train/             |          |
# |    actor_loss      | -219     |
# |    critic_loss     | 28.1     |
# |    ent_coef        | 0.0643   |
# |    ent_coef_loss   | 0.715    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 430268   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 470      |
# |    ep_rew_mean     | 671      |
# | time/              |          |
# |    episodes        | 340      |
# |    fps             | 45       |
# |    time_elapsed    | 2476     |
# |    total_timesteps | 111751   |
# | train/             |          |
# |    actor_loss      | -220     |
# |    critic_loss     | 25.2     |
# |    ent_coef        | 0.0611   |
# |    ent_coef_loss   | 0.459    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 446600   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 499      |
# |    ep_rew_mean     | 714      |
# | time/              |          |
# |    episodes        | 350      |
# |    fps             | 45       |
# |    time_elapsed    | 2632     |
# |    total_timesteps | 119426   |
# | train/             |          |
# |    actor_loss      | -231     |
# |    critic_loss     | 23.3     |
# |    ent_coef        | 0.0617   |
# |    ent_coef_loss   | 0.257    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 477300   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 530      |
# |    ep_rew_mean     | 763      |
# | time/              |          |
# |    episodes        | 360      |
# |    fps             | 45       |
# |    time_elapsed    | 2779     |
# |    total_timesteps | 126660   |
# | train/             |          |
# |    actor_loss      | -246     |
# |    critic_loss     | 27.1     |
# |    ent_coef        | 0.0645   |
# |    ent_coef_loss   | 0.426    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 506236   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 573      |
# |    ep_rew_mean     | 805      |
# | time/              |          |
# |    episodes        | 370      |
# |    fps             | 45       |
# |    time_elapsed    | 2970     |
# |    total_timesteps | 135876   |
# | train/             |          |
# |    actor_loss      | -251     |
# |    critic_loss     | 21.2     |
# |    ent_coef        | 0.0639   |
# |    ent_coef_loss   | -0.283   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 543100   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 591      |
# |    ep_rew_mean     | 837      |
# | time/              |          |
# |    episodes        | 380      |
# |    fps             | 45       |
# |    time_elapsed    | 3098     |
# |    total_timesteps | 142300   |
# | train/             |          |
# |    actor_loss      | -260     |
# |    critic_loss     | 20.1     |
# |    ent_coef        | 0.0621   |
# |    ent_coef_loss   | -1.03    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 568796   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 613      |
# |    ep_rew_mean     | 877      |
# | time/              |          |
# |    episodes        | 390      |
# |    fps             | 46       |
# |    time_elapsed    | 3237     |
# |    total_timesteps | 149105   |
# | train/             |          |
# |    actor_loss      | -263     |
# |    critic_loss     | 23.5     |
# |    ent_coef        | 0.0609   |
# |    ent_coef_loss   | 0.491    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 596016   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 621      |
# |    ep_rew_mean     | 921      |
# | time/              |          |
# |    episodes        | 400      |
# |    fps             | 45       |
# |    time_elapsed    | 3413     |
# |    total_timesteps | 156875   |
# | train/             |          |
# |    actor_loss      | -269     |
# |    critic_loss     | 25.8     |
# |    ent_coef        | 0.061    |
# |    ent_coef_loss   | -0.63    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 627096   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 659      |
# |    ep_rew_mean     | 991      |
# | time/              |          |
# |    episodes        | 410      |
# |    fps             | 46       |
# |    time_elapsed    | 3570     |
# |    total_timesteps | 164725   |
# | train/             |          |
# |    actor_loss      | -284     |
# |    critic_loss     | 24.8     |
# |    ent_coef        | 0.0636   |
# |    ent_coef_loss   | -0.613   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 658496   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 701      |
# |    ep_rew_mean     | 1.05e+03 |
# | time/              |          |
# |    episodes        | 420      |
# |    fps             | 46       |
# |    time_elapsed    | 3732     |
# |    total_timesteps | 172421   |
# | train/             |          |
# |    actor_loss      | -278     |
# |    critic_loss     | 22.6     |
# |    ent_coef        | 0.0636   |
# |    ent_coef_loss   | -0.349   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 689280   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 709      |
# |    ep_rew_mean     | 1.07e+03 |
# | time/              |          |
# |    episodes        | 430      |
# |    fps             | 46       |
# |    time_elapsed    | 3857     |
# |    total_timesteps | 178568   |
# | train/             |          |
# |    actor_loss      | -281     |
# |    critic_loss     | 22.2     |
# |    ent_coef        | 0.061    |
# |    ent_coef_loss   | -0.288   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 713868   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 728      |
# |    ep_rew_mean     | 1.11e+03 |
# | time/              |          |
# |    episodes        | 440      |
# |    fps             | 46       |
# |    time_elapsed    | 3983     |
# |    total_timesteps | 184559   |
# | train/             |          |
# |    actor_loss      | -286     |
# |    critic_loss     | 23.3     |
# |    ent_coef        | 0.0615   |
# |    ent_coef_loss   | 0.511    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 737832   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 716      |
# |    ep_rew_mean     | 1.11e+03 |
# | time/              |          |
# |    episodes        | 450      |
# |    fps             | 46       |
# |    time_elapsed    | 4132     |
# |    total_timesteps | 191042   |
# | train/             |          |
# |    actor_loss      | -295     |
# |    critic_loss     | 21.6     |
# |    ent_coef        | 0.0587   |
# |    ent_coef_loss   | 0.0025   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 763764   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 719      |
# |    ep_rew_mean     | 1.12e+03 |
# | time/              |          |
# |    episodes        | 460      |
# |    fps             | 46       |
# |    time_elapsed    | 4304     |
# |    total_timesteps | 198590   |
# | train/             |          |
# |    actor_loss      | -294     |
# |    critic_loss     | 33.6     |
# |    ent_coef        | 0.0606   |
# |    ent_coef_loss   | -0.444   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 793956   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 709      |
# |    ep_rew_mean     | 1.14e+03 |
# | time/              |          |
# |    episodes        | 470      |
# |    fps             | 46       |
# |    time_elapsed    | 4471     |
# |    total_timesteps | 206729   |
# | train/             |          |
# |    actor_loss      | -299     |
# |    critic_loss     | 27.4     |
# |    ent_coef        | 0.06     |
# |    ent_coef_loss   | 0.712    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 826512   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 721      |
# |    ep_rew_mean     | 1.17e+03 |
# | time/              |          |
# |    episodes        | 480      |
# |    fps             | 46       |
# |    time_elapsed    | 4623     |
# |    total_timesteps | 214429   |
# | train/             |          |
# |    actor_loss      | -316     |
# |    critic_loss     | 30.7     |
# |    ent_coef        | 0.0605   |
# |    ent_coef_loss   | -0.556   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 857312   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 725      |
# |    ep_rew_mean     | 1.2e+03  |
# | time/              |          |
# |    episodes        | 490      |
# |    fps             | 46       |
# |    time_elapsed    | 4776     |
# |    total_timesteps | 221646   |
# | train/             |          |
# |    actor_loss      | -323     |
# |    critic_loss     | 25.8     |
# |    ent_coef        | 0.0586   |
# |    ent_coef_loss   | -0.346   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 886180   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 736      |
# |    ep_rew_mean     | 1.2e+03  |
# | time/              |          |
# |    episodes        | 500      |
# |    fps             | 46       |
# |    time_elapsed    | 4984     |
# |    total_timesteps | 230428   |
# | train/             |          |
# |    actor_loss      | -337     |
# |    critic_loss     | 22.9     |
# |    ent_coef        | 0.0637   |
# |    ent_coef_loss   | -0.163   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 921308   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 753      |
# |    ep_rew_mean     | 1.24e+03 |
# | time/              |          |
# |    episodes        | 510      |
# |    fps             | 46       |
# |    time_elapsed    | 5181     |
# |    total_timesteps | 239992   |
# | train/             |          |
# |    actor_loss      | -353     |
# |    critic_loss     | 19.4     |
# |    ent_coef        | 0.0613   |
# |    ent_coef_loss   | 0.376    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 959564   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 733      |
# |    ep_rew_mean     | 1.21e+03 |
# | time/              |          |
# |    episodes        | 520      |
# |    fps             | 46       |
# |    time_elapsed    | 5296     |
# |    total_timesteps | 245752   |
# | train/             |          |
# |    actor_loss      | -365     |
# |    critic_loss     | 23.7     |
# |    ent_coef        | 0.0644   |
# |    ent_coef_loss   | -1       |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 982604   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 772      |
# |    ep_rew_mean     | 1.29e+03 |
# | time/              |          |
# |    episodes        | 530      |
# |    fps             | 46       |
# |    time_elapsed    | 5507     |
# |    total_timesteps | 255752   |
# | train/             |          |
# |    actor_loss      | -372     |
# |    critic_loss     | 32.4     |
# |    ent_coef        | 0.0648   |
# |    ent_coef_loss   | 1.92     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 1022604  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 795      |
# |    ep_rew_mean     | 1.35e+03 |
# | time/              |          |
# |    episodes        | 540      |
# |    fps             | 46       |
# |    time_elapsed    | 5671     |
# |    total_timesteps | 264017   |
# | train/             |          |
# |    actor_loss      | -398     |
# |    critic_loss     | 18.5     |
# |    ent_coef        | 0.0593   |
# |    ent_coef_loss   | -0.247   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 1055664  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 803      |
# |    ep_rew_mean     | 1.39e+03 |
# | time/              |          |
# |    episodes        | 550      |
# |    fps             | 46       |
# |    time_elapsed    | 5821     |
# |    total_timesteps | 271341   |
# | train/             |          |
# |    actor_loss      | -415     |
# |    critic_loss     | 19.4     |
# |    ent_coef        | 0.0649   |
# |    ent_coef_loss   | -0.171   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 1084960  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 812      |
# |    ep_rew_mean     | 1.45e+03 |
# | time/              |          |
# |    episodes        | 560      |
# |    fps             | 46       |
# |    time_elapsed    | 5995     |
# |    total_timesteps | 279754   |
# | train/             |          |
# |    actor_loss      | -423     |
# |    critic_loss     | 15.8     |
# |    ent_coef        | 0.0641   |
# |    ent_coef_loss   | 0.688    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 1118612  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 802      |
# |    ep_rew_mean     | 1.45e+03 |
# | time/              |          |
# |    episodes        | 570      |
# |    fps             | 46       |
# |    time_elapsed    | 6149     |
# |    total_timesteps | 286948   |
# | train/             |          |
# |    actor_loss      | -432     |
# |    critic_loss     | 21.9     |
# |    ent_coef        | 0.0648   |
# |    ent_coef_loss   | 0.314    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 1147388  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 809      |
# |    ep_rew_mean     | 1.51e+03 |
# | time/              |          |
# |    episodes        | 580      |
# |    fps             | 46       |
# |    time_elapsed    | 6344     |
# |    total_timesteps | 295373   |
# | train/             |          |
# |    actor_loss      | -434     |
# |    critic_loss     | 19.2     |
# |    ent_coef        | 0.0609   |
# |    ent_coef_loss   | 0.408    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 1181088  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 816      |
# |    ep_rew_mean     | 1.53e+03 |
# | time/              |          |
# |    episodes        | 590      |
# |    fps             | 46       |
# |    time_elapsed    | 6550     |
# |    total_timesteps | 303260   |
# | train/             |          |
# |    actor_loss      | -454     |
# |    critic_loss     | 18.3     |
# |    ent_coef        | 0.0633   |
# |    ent_coef_loss   | -0.324   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 1212636  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 816      |
# |    ep_rew_mean     | 1.56e+03 |
# | time/              |          |
# |    episodes        | 600      |
# |    fps             | 45       |
# |    time_elapsed    | 6805     |
# |    total_timesteps | 312000   |
# | train/             |          |
# |    actor_loss      | -462     |
# |    critic_loss     | 19.7     |
# |    ent_coef        | 0.0627   |
# |    ent_coef_loss   | 1.05     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 1247596  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 797      |
# |    ep_rew_mean     | 1.54e+03 |
# | time/              |          |
# |    episodes        | 610      |
# |    fps             | 45       |
# |    time_elapsed    | 6994     |
# |    total_timesteps | 319704   |
# | train/             |          |
# |    actor_loss      | -481     |
# |    critic_loss     | 221      |
# |    ent_coef        | 0.0642   |
# |    ent_coef_loss   | 1        |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 1278412  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 804      |
# |    ep_rew_mean     | 1.58e+03 |
# | time/              |          |
# |    episodes        | 620      |
# |    fps             | 45       |
# |    time_elapsed    | 7147     |
# |    total_timesteps | 326152   |
# | train/             |          |
# |    actor_loss      | -481     |
# |    critic_loss     | 26       |
# |    ent_coef        | 0.0681   |
# |    ent_coef_loss   | 0.821    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 1304204  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 771      |
# |    ep_rew_mean     | 1.55e+03 |
# | time/              |          |
# |    episodes        | 630      |
# |    fps             | 45       |
# |    time_elapsed    | 7313     |
# |    total_timesteps | 332890   |
# | train/             |          |
# |    actor_loss      | -492     |
# |    critic_loss     | 30.3     |
# |    ent_coef        | 0.0657   |
# |    ent_coef_loss   | -1.05    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 1331156  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 744      |
# |    ep_rew_mean     | 1.5e+03  |
# | time/              |          |
# |    episodes        | 640      |
# |    fps             | 45       |
# |    time_elapsed    | 7461     |
# |    total_timesteps | 338455   |
# | train/             |          |
# |    actor_loss      | -495     |
# |    critic_loss     | 28.9     |
# |    ent_coef        | 0.0698   |
# |    ent_coef_loss   | 0.268    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 1353416  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 743      |
# |    ep_rew_mean     | 1.5e+03  |
# | time/              |          |
# |    episodes        | 650      |
# |    fps             | 45       |
# |    time_elapsed    | 7661     |
# |    total_timesteps | 345652   |
# | train/             |          |
# |    actor_loss      | -499     |
# |    critic_loss     | 22.7     |
# |    ent_coef        | 0.0714   |
# |    ent_coef_loss   | 0.467    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 1382204  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 741      |
# |    ep_rew_mean     | 1.52e+03 |
# | time/              |          |
# |    episodes        | 660      |
# |    fps             | 44       |
# |    time_elapsed    | 7895     |
# |    total_timesteps | 353872   |
# | train/             |          |
# |    actor_loss      | -510     |
# |    critic_loss     | 30.5     |
# |    ent_coef        | 0.0668   |
# |    ent_coef_loss   | -0.15    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 1415084  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 743      |
# |    ep_rew_mean     | 1.54e+03 |
# | time/              |          |
# |    episodes        | 670      |
# |    fps             | 44       |
# |    time_elapsed    | 8098     |
# |    total_timesteps | 361288   |
# | train/             |          |
# |    actor_loss      | -534     |
# |    critic_loss     | 17.9     |
# |    ent_coef        | 0.0619   |
# |    ent_coef_loss   | -0.256   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 1444748  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 747      |
# |    ep_rew_mean     | 1.57e+03 |
# | time/              |          |
# |    episodes        | 680      |
# |    fps             | 44       |
# |    time_elapsed    | 8327     |
# |    total_timesteps | 370074   |
# | train/             |          |
# |    actor_loss      | -553     |
# |    critic_loss     | 13.6     |
# |    ent_coef        | 0.0626   |
# |    ent_coef_loss   | -0.152   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 1479892  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 760      |
# |    ep_rew_mean     | 1.64e+03 |
# | time/              |          |
# |    episodes        | 690      |
# |    fps             | 44       |
# |    time_elapsed    | 8567     |
# |    total_timesteps | 379211   |
# | train/             |          |
# |    actor_loss      | -574     |
# |    critic_loss     | 20.7     |
# |    ent_coef        | 0.0643   |
# |    ent_coef_loss   | -1.39    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 1516440  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 760      |
# |    ep_rew_mean     | 1.7e+03  |
# | time/              |          |
# |    episodes        | 700      |
# |    fps             | 44       |
# |    time_elapsed    | 8800     |
# |    total_timesteps | 388029   |
# | train/             |          |
# |    actor_loss      | -602     |
# |    critic_loss     | 18.1     |
# |    ent_coef        | 0.0674   |
# |    ent_coef_loss   | 0.00726  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 1551712  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 750      |
# |    ep_rew_mean     | 1.71e+03 |
# | time/              |          |
# |    episodes        | 710      |
# |    fps             | 44       |
# |    time_elapsed    | 8956     |
# |    total_timesteps | 394681   |
# | train/             |          |
# |    actor_loss      | -616     |
# |    critic_loss     | 18.5     |
# |    ent_coef        | 0.0653   |
# |    ent_coef_loss   | 0.0508   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 1578320  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 782      |
# |    ep_rew_mean     | 1.84e+03 |
# | time/              |          |
# |    episodes        | 720      |
# |    fps             | 44       |
# |    time_elapsed    | 9184     |
# |    total_timesteps | 404378   |
# | train/             |          |
# |    actor_loss      | -622     |
# |    critic_loss     | 13.6     |
# |    ent_coef        | 0.0674   |
# |    ent_coef_loss   | -0.216   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 1617108  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 788      |
# |    ep_rew_mean     | 1.88e+03 |
# | time/              |          |
# |    episodes        | 730      |
# |    fps             | 43       |
# |    time_elapsed    | 9374     |
# |    total_timesteps | 411681   |
# | train/             |          |
# |    actor_loss      | -631     |
# |    critic_loss     | 19.5     |
# |    ent_coef        | 0.0685   |
# |    ent_coef_loss   | 0.203    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 1646320  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 801      |
# |    ep_rew_mean     | 1.94e+03 |
# | time/              |          |
# |    episodes        | 740      |
# |    fps             | 43       |
# |    time_elapsed    | 9536     |
# |    total_timesteps | 418574   |
# | train/             |          |
# |    actor_loss      | -629     |
# |    critic_loss     | 20       |
# |    ent_coef        | 0.0732   |
# |    ent_coef_loss   | 0.115    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 1673892  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 818      |
# |    ep_rew_mean     | 2.03e+03 |
# | time/              |          |
# |    episodes        | 750      |
# |    fps             | 43       |
# |    time_elapsed    | 9766     |
# |    total_timesteps | 427444   |
# | train/             |          |
# |    actor_loss      | -652     |
# |    critic_loss     | 12.2     |
# |    ent_coef        | 0.0693   |
# |    ent_coef_loss   | -0.0401  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 1709372  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 812      |
# |    ep_rew_mean     | 2.04e+03 |
# | time/              |          |
# |    episodes        | 760      |
# |    fps             | 43       |
# |    time_elapsed    | 9964     |
# |    total_timesteps | 435116   |
# | train/             |          |
# |    actor_loss      | -656     |
# |    critic_loss     | 23.9     |
# |    ent_coef        | 0.0745   |
# |    ent_coef_loss   | 0.269    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 1740060  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 822      |
# |    ep_rew_mean     | 2.11e+03 |
# | time/              |          |
# |    episodes        | 770      |
# |    fps             | 43       |
# |    time_elapsed    | 10186    |
# |    total_timesteps | 443486   |
# | train/             |          |
# |    actor_loss      | -671     |
# |    critic_loss     | 16.1     |
# |    ent_coef        | 0.0711   |
# |    ent_coef_loss   | -0.323   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 1773540  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 813      |
# |    ep_rew_mean     | 2.11e+03 |
# | time/              |          |
# |    episodes        | 780      |
# |    fps             | 43       |
# |    time_elapsed    | 10408    |
# |    total_timesteps | 451353   |
# | train/             |          |
# |    actor_loss      | -670     |
# |    critic_loss     | 20.8     |
# |    ent_coef        | 0.0698   |
# |    ent_coef_loss   | -0.256   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 1805008  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 805      |
# |    ep_rew_mean     | 2.13e+03 |
# | time/              |          |
# |    episodes        | 790      |
# |    fps             | 43       |
# |    time_elapsed    | 10637    |
# |    total_timesteps | 459738   |
# | train/             |          |
# |    actor_loss      | -692     |
# |    critic_loss     | 45.9     |
# |    ent_coef        | 0.0789   |
# |    ent_coef_loss   | 0.521    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 1838548  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 805      |
# |    ep_rew_mean     | 2.16e+03 |
# | time/              |          |
# |    episodes        | 800      |
# |    fps             | 43       |
# |    time_elapsed    | 10872    |
# |    total_timesteps | 468485   |
# | train/             |          |
# |    actor_loss      | -721     |
# |    critic_loss     | 24.1     |
# |    ent_coef        | 0.0735   |
# |    ent_coef_loss   | 1.33     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 1873536  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 823      |
# |    ep_rew_mean     | 2.27e+03 |
# | time/              |          |
# |    episodes        | 810      |
# |    fps             | 42       |
# |    time_elapsed    | 11102    |
# |    total_timesteps | 476976   |
# | train/             |          |
# |    actor_loss      | -733     |
# |    critic_loss     | 20.4     |
# |    ent_coef        | 0.0798   |
# |    ent_coef_loss   | 0.37     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 1907500  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 798      |
# |    ep_rew_mean     | 2.21e+03 |
# | time/              |          |
# |    episodes        | 820      |
# |    fps             | 42       |
# |    time_elapsed    | 11300    |
# |    total_timesteps | 484161   |
# | train/             |          |
# |    actor_loss      | -744     |
# |    critic_loss     | 19.2     |
# |    ent_coef        | 0.0874   |
# |    ent_coef_loss   | -0.562   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 1936240  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 776      |
# |    ep_rew_mean     | 2.16e+03 |
# | time/              |          |
# |    episodes        | 830      |
# |    fps             | 42       |
# |    time_elapsed    | 11446    |
# |    total_timesteps | 489306   |
# | train/             |          |
# |    actor_loss      | -752     |
# |    critic_loss     | 41.4     |
# |    ent_coef        | 0.0896   |
# |    ent_coef_loss   | 0.0285   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 1956820  |
# ...
# |    actor_loss      | -910     |
# |    critic_loss     | 60.6     |
# |    ent_coef        | 0.111    |
# |    ent_coef_loss   | 0.681    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 2634844  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 714      |
# |    ep_rew_mean     | 2.44e+03 |
# | time/              |          |
# |    episodes        | 1070     |
# |    fps             | 40       |
# |    time_elapsed    | 16256    |
# |    total_timesteps | 666100   |
# | train/             |          |
# |    actor_loss      | -907     |
# |    critic_loss     | 61.5     |
# |    ent_coef        | 0.109    |
# |    ent_coef_loss   | -0.0735  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 2663996  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 710      |
# |    ep_rew_mean     | 2.42e+03 |
# | time/              |          |
# |    episodes        | 1080     |
# |    fps             | 40       |
# |    time_elapsed    | 16415    |
# |    total_timesteps | 672961   |
# | train/             |          |
# |    actor_loss      | -909     |
# |    critic_loss     | 42.1     |
# |    ent_coef        | 0.107    |
# |    ent_coef_loss   | -0.443   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 2691440  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 698      |
# |    ep_rew_mean     | 2.37e+03 |
# | time/              |          |
# |    episodes        | 1090     |
# |    fps             | 41       |
# |    time_elapsed    | 16540    |
# |    total_timesteps | 678246   |
# | train/             |          |
# |    actor_loss      | -902     |
# |    critic_loss     | 86.7     |
# |    ent_coef        | 0.108    |
# |    ent_coef_loss   | 0.0377   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 2712580  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 710      |
# |    ep_rew_mean     | 2.44e+03 |
# | time/              |          |
# |    episodes        | 1100     |
# |    fps             | 41       |
# |    time_elapsed    | 16755    |
# |    total_timesteps | 687003   |
# | train/             |          |
# |    actor_loss      | -921     |
# |    critic_loss     | 51.2     |
# |    ent_coef        | 0.104    |
# |    ent_coef_loss   | -0.304   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 2747608  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 701      |
# |    ep_rew_mean     | 2.43e+03 |
# | time/              |          |
# |    episodes        | 1110     |
# |    fps             | 41       |
# |    time_elapsed    | 16909    |
# |    total_timesteps | 693680   |
# | train/             |          |
# |    actor_loss      | -927     |
# |    critic_loss     | 51       |
# |    ent_coef        | 0.103    |
# |    ent_coef_loss   | 0.616    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 2774316  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 673      |
# |    ep_rew_mean     | 2.32e+03 |
# | time/              |          |
# |    episodes        | 1120     |
# |    fps             | 41       |
# |    time_elapsed    | 17061    |
# |    total_timesteps | 700116   |
# | train/             |          |
# |    actor_loss      | -923     |
# |    critic_loss     | 47.7     |
# |    ent_coef        | 0.104    |
# |    ent_coef_loss   | -0.198   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 2800060  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 691      |
# |    ep_rew_mean     | 2.39e+03 |
# | time/              |          |
# |    episodes        | 1130     |
# |    fps             | 41       |
# |    time_elapsed    | 17242    |
# |    total_timesteps | 708003   |
# | train/             |          |
# |    actor_loss      | -926     |
# |    critic_loss     | 45.1     |
# |    ent_coef        | 0.102    |
# |    ent_coef_loss   | 0.0813   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 2831608  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 710      |
# |    ep_rew_mean     | 2.49e+03 |
# | time/              |          |
# |    episodes        | 1140     |
# |    fps             | 41       |
# |    time_elapsed    | 17443    |
# |    total_timesteps | 716588   |
# | train/             |          |
# |    actor_loss      | -940     |
# |    critic_loss     | 49.3     |
# |    ent_coef        | 0.103    |
# |    ent_coef_loss   | 0.13     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 2865948  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 718      |
# |    ep_rew_mean     | 2.53e+03 |
# | time/              |          |
# |    episodes        | 1150     |
# |    fps             | 41       |
# |    time_elapsed    | 17643    |
# |    total_timesteps | 724954   |
# | train/             |          |
# |    actor_loss      | -943     |
# |    critic_loss     | 50.1     |
# |    ent_coef        | 0.105    |
# |    ent_coef_loss   | 0.749    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 2899412  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 731      |
# |    ep_rew_mean     | 2.57e+03 |
# | time/              |          |
# |    episodes        | 1160     |
# |    fps             | 41       |
# |    time_elapsed    | 17804    |
# |    total_timesteps | 731890   |
# | train/             |          |
# |    actor_loss      | -955     |
# |    critic_loss     | 64.9     |
# |    ent_coef        | 0.108    |
# |    ent_coef_loss   | -0.205   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 2927156  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 718      |
# |    ep_rew_mean     | 2.54e+03 |
# | time/              |          |
# |    episodes        | 1170     |
# |    fps             | 41       |
# |    time_elapsed    | 17944    |
# |    total_timesteps | 737925   |
# | train/             |          |
# |    actor_loss      | -951     |
# |    critic_loss     | 52.8     |
# |    ent_coef        | 0.102    |
# |    ent_coef_loss   | 1.35     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 2951296  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 717      |
# |    ep_rew_mean     | 2.54e+03 |
# | time/              |          |
# |    episodes        | 1180     |
# |    fps             | 41       |
# |    time_elapsed    | 18110    |
# |    total_timesteps | 744628   |
# | train/             |          |
# |    actor_loss      | -954     |
# |    critic_loss     | 60.2     |
# |    ent_coef        | 0.107    |
# |    ent_coef_loss   | -0.397   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 2978108  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 734      |
# |    ep_rew_mean     | 2.62e+03 |
# | time/              |          |
# |    episodes        | 1190     |
# |    fps             | 41       |
# |    time_elapsed    | 18271    |
# |    total_timesteps | 751609   |
# | train/             |          |
# |    actor_loss      | -970     |
# |    critic_loss     | 73.2     |
# |    ent_coef        | 0.103    |
# |    ent_coef_loss   | -0.0562  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 3006032  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 720      |
# |    ep_rew_mean     | 2.58e+03 |
# | time/              |          |
# |    episodes        | 1200     |
# |    fps             | 41       |
# |    time_elapsed    | 18440    |
# |    total_timesteps | 758978   |
# | train/             |          |
# |    actor_loss      | -984     |
# |    critic_loss     | 52.6     |
# |    ent_coef        | 0.113    |
# |    ent_coef_loss   | 0.171    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 3035508  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 710      |
# |    ep_rew_mean     | 2.55e+03 |
# | time/              |          |
# |    episodes        | 1210     |
# |    fps             | 41       |
# |    time_elapsed    | 18579    |
# |    total_timesteps | 764709   |
# | train/             |          |
# |    actor_loss      | -993     |
# |    critic_loss     | 41.8     |
# |    ent_coef        | 0.109    |
# |    ent_coef_loss   | -1.15    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 3058432  |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 716       |
# |    ep_rew_mean     | 2.57e+03  |
# | time/              |           |
# |    episodes        | 1220      |
# |    fps             | 41        |
# |    time_elapsed    | 18743     |
# |    total_timesteps | 771727    |
# | train/             |           |
# |    actor_loss      | -1.01e+03 |
# |    critic_loss     | 43.9      |
# |    ent_coef        | 0.104     |
# |    ent_coef_loss   | 0.0942    |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 3086504   |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 708      |
# |    ep_rew_mean     | 2.56e+03 |
# | time/              |          |
# |    episodes        | 1230     |
# |    fps             | 41       |
# |    time_elapsed    | 18912    |
# |    total_timesteps | 778830   |
# | train/             |          |
# |    actor_loss      | -1e+03   |
# |    critic_loss     | 55.2     |
# |    ent_coef        | 0.101    |
# |    ent_coef_loss   | -0.591   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 3114916  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 684      |
# |    ep_rew_mean     | 2.46e+03 |
# | time/              |          |
# |    episodes        | 1240     |
# |    fps             | 41       |
# |    time_elapsed    | 19052    |
# |    total_timesteps | 785001   |
# | train/             |          |
# |    actor_loss      | -1e+03   |
# |    critic_loss     | 44.4     |
# |    ent_coef        | 0.107    |
# |    ent_coef_loss   | 0.952    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 3139600  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 680      |
# |    ep_rew_mean     | 2.44e+03 |
# | time/              |          |
# |    episodes        | 1250     |
# |    fps             | 41       |
# |    time_elapsed    | 19237    |
# |    total_timesteps | 792964   |
# | train/             |          |
# |    actor_loss      | -1e+03   |
# |    critic_loss     | 620      |
# |    ent_coef        | 0.106    |
# |    ent_coef_loss   | 0.0163   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 3171452  |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 671       |
# |    ep_rew_mean     | 2.42e+03  |
# | time/              |           |
# |    episodes        | 1260      |
# |    fps             | 41        |
# |    time_elapsed    | 19375     |
# |    total_timesteps | 798943    |
# | train/             |           |
# |    actor_loss      | -1.02e+03 |
# |    critic_loss     | 36.7      |
# |    ent_coef        | 0.109     |
# |    ent_coef_loss   | 0.011     |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 3195368   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 680       |
# |    ep_rew_mean     | 2.46e+03  |
# | time/              |           |
# |    episodes        | 1270      |
# |    fps             | 41        |
# |    time_elapsed    | 19546     |
# |    total_timesteps | 805906    |
# | train/             |           |
# |    actor_loss      | -1.01e+03 |
# |    critic_loss     | 44.5      |
# |    ent_coef        | 0.104     |
# |    ent_coef_loss   | -0.8      |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 3223220   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 685       |
# |    ep_rew_mean     | 2.49e+03  |
# | time/              |           |
# |    episodes        | 1280      |
# |    fps             | 41        |
# |    time_elapsed    | 19725     |
# |    total_timesteps | 813099    |
# | train/             |           |
# |    actor_loss      | -1.01e+03 |
# |    critic_loss     | 31.4      |
# |    ent_coef        | 0.102     |
# |    ent_coef_loss   | 0.819     |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 3251992   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 679       |
# |    ep_rew_mean     | 2.47e+03  |
# | time/              |           |
# |    episodes        | 1290      |
# |    fps             | 41        |
# |    time_elapsed    | 19871     |
# |    total_timesteps | 819483    |
# | train/             |           |
# |    actor_loss      | -1.02e+03 |
# |    critic_loss     | 77        |
# |    ent_coef        | 0.104     |
# |    ent_coef_loss   | -0.0116   |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 3277528   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 665       |
# |    ep_rew_mean     | 2.42e+03  |
# | time/              |           |
# |    episodes        | 1300      |
# |    fps             | 41        |
# |    time_elapsed    | 20016     |
# |    total_timesteps | 825510    |
# | train/             |           |
# |    actor_loss      | -1.03e+03 |
# |    critic_loss     | 173       |
# |    ent_coef        | 0.103     |
# |    ent_coef_loss   | -0.273    |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 3301636   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 674       |
# |    ep_rew_mean     | 2.46e+03  |
# | time/              |           |
# |    episodes        | 1310      |
# |    fps             | 41        |
# |    time_elapsed    | 20167     |
# |    total_timesteps | 832114    |
# | train/             |           |
# |    actor_loss      | -1.03e+03 |
# |    critic_loss     | 59        |
# |    ent_coef        | 0.105     |
# |    ent_coef_loss   | 0.351     |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 3328052   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 683       |
# |    ep_rew_mean     | 2.5e+03   |
# | time/              |           |
# |    episodes        | 1320      |
# |    fps             | 41        |
# |    time_elapsed    | 20352     |
# |    total_timesteps | 840044    |
# | train/             |           |
# |    actor_loss      | -1.03e+03 |
# |    critic_loss     | 46.5      |
# |    ent_coef        | 0.104     |
# |    ent_coef_loss   | -0.104    |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 3359772   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 689       |
# |    ep_rew_mean     | 2.52e+03  |
# | time/              |           |
# |    episodes        | 1330      |
# |    fps             | 41        |
# |    time_elapsed    | 20532     |
# |    total_timesteps | 847709    |
# | train/             |           |
# |    actor_loss      | -1.05e+03 |
# |    critic_loss     | 35.4      |
# |    ent_coef        | 0.0942    |
# |    ent_coef_loss   | -0.353    |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 3390432   |
# ----------------------------------
