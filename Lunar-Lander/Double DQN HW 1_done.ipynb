# %% [markdown]
# # Double DQN

# %% [markdown]
# In this notebook, we will implement Deep Q-Learning Reinforcement learning algorithm for Lunar Lander Environment.

# %% [markdown]
# ## Lunar Lander

# %% [markdown]
# This environment is a classic rocket trajectory optimization problem. The landing pad is always at coordinates (0,0). The state is an 8-dimensional vector: the coordinates of the lander in x & y, its linear velocities in x & y, its angle, its angular velocity, and two booleans that represent whether each leg is in contact with the ground or not.
#
# There are four discrete actions available:<br>
# - 0: do nothing<br>
# - 1: fire left orientation engine<br>
# - 2: fire main engine<br>
# - 3: fire right orientation engine<br>
#
# After every step a reward is granted. The total reward of an episode is the sum of the rewards for all the steps within that episode.
#
# For each step, the reward:
#
# - is increased/decreased the closer/further the lander is to the landing pad.
#
# - is increased/decreased the slower/faster the lander is moving.
#
# - is decreased the more the lander is tilted (angle not horizontal).
#
# - is increased by 10 points for each leg that is in contact with the ground.
#
# - is decreased by 0.03 points each frame a side engine is firing.
#
# - is decreased by 0.3 points each frame the main engine is firing.
#
# The episode receive an additional reward of -100 or +100 points for crashing or landing safely respectively.
#
# An episode is considered a solution if it scores at least 200 points.
#
#
# You can read more the LunarLander environment [here](https://gymnasium.farama.org/environments/box2d/lunar_lander/)
#
# ![LunarLander](https://gymnasium.farama.org/_images/lunar_lander.gif)

# %% [markdown]
# ## Deep Q-Learning

# %% [markdown]
# The main idea behind Q-learning is that if we had a function
# $Q^*: State \times Action \rightarrow \mathbb{R}$, that could tell
# us what our return would be, if we were to take an action in a given
# state, then we could easily construct a policy that maximizes our
# rewards:
#
# \begin{align}\pi^*(s) = \arg\!\max_a \ Q^*(s, a)\end{align}
#
# But this is not scalable. Must compute $Q(s,a)$ for every state-action pair. If state is e.g. current game state pixels, computationally infeasible to compute for entire state space! But, since neural networks are universal function
# approximators, we can simply create one and train it to resemble
# $Q^*$.
#
# For our training update rule, we'll use a fact that every $Q$
# function for some policy obeys the Bellman equation:
#
# \begin{align}Q^{\pi}(s, a) = r + \gamma Q^{\pi}(s', \pi(s'))\end{align}
#
# The difference between the two sides of the equality is known as the
# temporal difference error, $\delta$:
#
# \begin{align}\delta = Q(s, a) - (r + \gamma \max_a Q(s', a))\end{align}
#
# To minimise this error, we will use the `Huber
# loss <https://en.wikipedia.org/wiki/Huber_loss>`__. The Huber loss acts
# like the mean squared error when the error is small, but like the mean
# absolute error when the error is large - this makes it more robust to
# outliers when the estimates of $Q$ are very noisy. We calculate
# this over a batch of transitions, $B$, sampled from the replay
# memory:
#
# \begin{align}\mathcal{L} = \frac{1}{|B|}\sum_{(s, a, s', r) \ \in \ B} \mathcal{L}(\delta)\end{align}
#
# \begin{align}\text{where} \quad \mathcal{L}(\delta) = \begin{cases}
#      \frac{1}{2}{\delta^2}  & \text{for } |\delta| \le 1, \\
#      |\delta| - \frac{1}{2} & \text{otherwise.}
#    \end{cases}\end{align}

# %% [markdown]
# ### Double Deep Q-Learning

# %% [markdown]
# We will implement Double Deep Q-Learning here. Double Deep Q-Learning is used to reduce the maximaztion bias in Q-Learning. This entails separate action selection and action evaluation in the target value.
#
# - Use the current network to select the max action for the next state
# and then use the target network to get the target Q-value for that
# action.

# %% [markdown]
# ![ddqn.png](data:image/png;base64,...)

# %% [markdown]
# [Image Source](https://leejungi.github.io/posts/Dueling-DQN/)

# %%
# !pip3 install -q swig
# !pip3 install -q gym[box2d]
# Out:
# WARNING: You are using pip version 21.2.4; however, version 24.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# zsh:1: no matches found: gym[box2d]

# %%
import gym
import math
import random
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from collections import namedtuple
from itertools import count
from PIL import Image
from collections import deque
import collections
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torchvision.transforms as T

# %%
# if gpu is to be used
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cpu')

# %%
# Create the environment
env = gym.make("LunarLander-v2")

# %% [markdown]
# ### Experience Replay

# %% [markdown]
# Learning from batches of consecutive samples is problematic as the sample are correlated and it can create a bad feedback loop if one action is dominated in the samples.
#
# We can address these problems using an experience replay memory. It maintains a record for all the transitions experienced. The agent is then trained by sampling random minibatches from the replay memory.

# %%
class MemoryBuffer:
    def __init__(self, max_size):

        # The size of the memory buffer, i.e. how many transitions can be kept
        self.memory_size = max_size
        # A counter for the number of transitions stored in the memory
        self.trans_counter = 0
        # A buffer containing the transitions 
        self.buffer = collections.deque(maxlen=self.memory_size)

    def store_transition(self, state, action, reward, new_state, terminal):
        # Save a transition tuple into the memory buffer.
        transition = (state, action, reward, new_state, terminal)
        self.buffer.append(transition)

        # Update the counter, and reset if it the memory is full
        self.trans_counter = (self.trans_counter + 1) % self.memory_size

    def random_sample(self, batch_size):
        
        # Ensure that the sampling operation does not attempt to draw more transitions than are currently available in the memory buffer
        if len(self.buffer) < batch_size:
            batch_size = len(self.buffer)

        # Sample a batch of transitions
        transitions = random.sample(self.buffer, k=batch_size)
        states, actions, rewards, new_states, terminals = zip(*transitions)

        # Return all the elements of the transition
        return (
            torch.tensor(states, dtype=torch.float32, device=device),
            torch.tensor(actions, dtype=torch.long, device=device),
            torch.tensor(rewards, dtype=torch.float32, device=device),
            torch.tensor(new_states, dtype=torch.float32, device=device),
            torch.tensor(terminals, dtype=torch.float32, device=device)
        )

# %% [markdown]
# ### Q-Network

# %%
class QNN(nn.Module):
    def __init__(self, state_size, action_size, seed):
        # Initialize a neural network model for Q-learning.
        super().__init__()
        self.seed = torch.manual_seed(seed)
        self.fc1 = nn.Linear(state_size, 128)
        self.fc2 = nn.Linear(128, 128)
        self.fc3 = nn.Linear(128, action_size)
        
    def forward(self, state):
        # Forward pass of the neural network.

        # Pass the input state through the first layer and apply ReLU activation.
        x = F.relu(self.fc1(state))
        # Pass the result through the second layer and apply ReLU activation.
        x = F.relu(self.fc2(x))
        
        # Pass the result through the third layer (output layer) without activation.
        # This layer outputs Q-values for each action.
        return self.fc3(x)

# %% [markdown]
# ### Exploration vs Exploitation

# %% [markdown]
# Notice that Q-learning only learns about the states and actions it visits. What if an optimal state remains unvisited due to not being explored. The agent should sometimes pick suboptimal actions in order to visit new states and actions. <br>
#
# A simple strategy is to use an $\epsilon$-greedy policy. According to this policy, the agent takes a random action with epsilon probability. The value of epsilon is high at the start of training and low towards the end. So, the agent explores more at the start and then exploit the learned policy more at the end.

# %% [markdown]
# ### Hyperparameters

# %%
# Hyperparameters
num_episodes = 2000  # number of episodes for training
gamma = 0.99  # discount factor
batch_size=128 # batch size for training

epsilon = 1.0  # exploration rate
epsilon_dec = 0.995  # decay rate of epsilon
epsilon_end = 0.01  # minimum value of epsilon

lr = 0.001  # learning rate
max_buffer = 10000  # maximum size of replay memory
replace_q_target = 100  # frequency to update the target network
LEARN_EVERY = 3
max_steps = 1000  # maximum number of steps per episode

# %% [markdown]
# ### Training

# %%
class Agent:
    def __init__(self, gamma, epsilon, batch_size, lr,
                 epsilon_dec, epsilon_end, max_buffer):
        # Initialize a reinforcement learning agent.
        self.memory = MemoryBuffer(max_buffer)
        self.gamma = gamma
        self.epsilon = epsilon
        self.epsilon_dec = epsilon_dec
        self.epsilon_min = epsilon_end
        self.batch_size = batch_size

    def save_transition(self, state, action, reward, new_state, done):
        # Funtion to just save transition into the agent's memory buffer.
        self.memory.store_transition(state, action, reward, new_state, done)

    def choose_action(self, state):
        # Choose an action based on the current state using the epsilon-greedy policy.
        if np.random.random() > self.epsilon:
            # Exploit
            state = torch.tensor(state, dtype=torch.float32, device=device)
            with torch.no_grad():
                # Pass state through NN
                action_values = self.q_func(state.unsqueeze(0))
            # Return action with higest q value    
            return torch.argmax(action_values, dim=1).item()
        else:
            # Explore by choosing random action
            return np.random.choice(range(4))

    def reduce_epsilon(self):
        # Reduce the exploration rate epsilon.
        self.epsilon = max(self.epsilon * self.epsilon_dec, self.epsilon_min)



class DoubleQAgent(Agent):
    def __init__(self, gamma, epsilon, batch_size, lr,
                 epsilon_dec, epsilon_end,
                 mem_size, replace_q_target):
        # Initialize a double Q-learning agent.
        super().__init__(gamma, epsilon, batch_size, lr, epsilon_dec, epsilon_end, mem_size)
        self.replace_q_target = replace_q_target
        self.q_func = QNN(8, 4, 42).to(device) # Main Q network
        self.q_func_target = QNN(8, 4, 42).to(device) # Target Q network
        self.optimizer = optim.Adam(self.q_func.parameters(), lr=lr)



    def learn(self):
        # Update the Q-network based on experiences in the memory buffer.

        # If the memory buffer is not full enough, do not train
        if len(self.memory.buffer) < self.batch_size:
            return
        
        # Sample a batch of transitions from the memory buffer
        states, actions, rewards, new_states, terminals = self.memory.random_sample(self.batch_size)
        
        # Compute Q-values for the next state using the target Q-network
        q_next = self.q_func_target(new_states).detach().max(1)[0].unsqueeze(1)

        # Compute the updated Q-values using Double Q-learning update rule
        q_updated = rewards + self.gamma * q_next * (1 - terminals)
        q = self.q_func(states).gather(1, actions.unsqueeze(1))
        
        # Calculate the loss between predicted Q-values and updated Q-values
        loss = F.mse_loss(q, q_updated)


        # Perform backpropagation and optimization step
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()
        

        # Periodically update the target Q-network with the weights of the main Q-network
        if self.memory.trans_counter % self.replace_q_target == 0:
            self.q_func_target.load_state_dict(self.q_func.state_dict())
        
        self.reduce_epsilon()

# %%
import gym
import time
import numpy as np
import matplotlib.pyplot as plt

def train_agent(n_episodes):
    print(f"Training a DDQN agent on {n_episodes} episodes.")
    
    env = gym.make("LunarLander-v2")

    # Initialize the Double Q-learning agent 
    agent = DoubleQAgent(gamma, epsilon, batch_size, lr, 
                         epsilon_dec, epsilon_end, max_buffer, replace_q_target)
    
    # Initialize lists to store scores (rewards obtained by each episode) and average scores
    scores = []
    avg_scores = []

    for i in range(n_episodes):
        terminated = False
        truncated = False
        score = 0
        state = env.reset()[0]
        steps = 0
        
        while not (terminated or truncated) and steps < max_steps:
            # Choose action based on current state
            action = agent.choose_action(state)

            # Take action and get new state, reward, and termination status
            new_state, reward, terminated, truncated, _ = env.step(action)
            # Save transition into memory buffer
            agent.save_transition(state, action, reward, new_state, terminated)
            # Update current state to new state
            state = new_state
            
            # Perform learning step every n steps
            if steps > 0 and steps % LEARN_EVERY == 0:
                agent.learn()
            
            # Increment step counter and accumulate score
            steps += 1
            score += reward
        
        # Record score for current episode
        scores.append(score)
        
        # Calculate average score for the last 100 episodes
        avg_score = np.mean(scores[max(0, i-100):(i+1)])
        avg_scores.append(avg_score)
        
        # Print progress every 10 episodes
        if i % 10 == 0:
            print(f"Episode {i}/{n_episodes} - Score: {score:.2f} - Average Score: {avg_score:.2f} - Epsilon: {agent.epsilon:.2f}")

    # Plotting the results
    plt.figure(figsize=(10, 5))
    plt.plot(range(n_episodes), scores, label="Score per Episode")
    plt.plot(range(n_episodes), avg_scores, label="Average Score (100 episodes)")
    plt.xlabel("Episode")
    plt.ylabel("Score")
    plt.title("Scores over Episodes")
    plt.legend()
    plt.show()

    return agent

# %%
agent = train_agent(num_episodes)
# Out:
# Training a DDQN agent on 2000 episodes.
# Episode 0/2000 - Score: -60.89 - Average Score: -60.89 - Epsilon: 1.00
# /var/folders/kk/cjvhrlcd2d3b4mbcr9q9bh900000gp/T/ipykernel_93824/1107844922.py:67: UserWarning: Using a target size (torch.Size([128, 128])) that is different to the input size (torch.Size([128, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   loss = F.mse_loss(q, q_updated)
# Episode 10/2000 - Score: -286.14 - Average Score: -246.64 - Epsilon: 0.27
# Episode 20/2000 - Score: -210.53 - Average Score: -262.22 - Epsilon: 0.06
# Episode 30/2000 - Score: -129.74 - Average Score: -264.70 - Epsilon: 0.01
# Episode 40/2000 - Score: -839.62 - Average Score: -281.26 - Epsilon: 0.01
# Episode 50/2000 - Score: -405.73 - Average Score: -305.26 - Epsilon: 0.01
# Episode 60/2000 - Score: -375.69 - Average Score: -293.32 - Epsilon: 0.01
# Episode 70/2000 - Score: -539.22 - Average Score: -302.34 - Epsilon: 0.01
# Episode 80/2000 - Score: -48.68 - Average Score: -297.92 - Epsilon: 0.01
# Episode 90/2000 - Score: -282.77 - Average Score: -297.59 - Epsilon: 0.01
# Episode 100/2000 - Score: -309.74 - Average Score: -303.33 - Epsilon: 0.01
# Episode 110/2000 - Score: -259.64 - Average Score: -303.14 - Epsilon: 0.01
# Episode 120/2000 - Score: -226.94 - Average Score: -299.73 - Epsilon: 0.01
# Episode 130/2000 - Score: -275.53 - Average Score: -299.01 - Epsilon: 0.01
# Episode 140/2000 - Score: -134.50 - Average Score: -299.86 - Epsilon: 0.01
# Episode 150/2000 - Score: -436.20 - Average Score: -281.48 - Epsilon: 0.01
# Episode 160/2000 - Score: -355.41 - Average Score: -282.75 - Epsilon: 0.01
# Episode 170/2000 - Score: -150.54 - Average Score: -275.90 - Epsilon: 0.01
# Episode 180/2000 - Score: -398.18 - Average Score: -271.91 - Epsilon: 0.01
# Episode 190/2000 - Score: -24.93 - Average Score: -274.46 - Epsilon: 0.01
# Episode 200/2000 - Score: -275.97 - Average Score: -266.64 - Epsilon: 0.01
# Episode 210/2000 - Score: -116.88 - Average Score: -268.17 - Epsilon: 0.01
# Episode 220/2000 - Score: -302.12 - Average Score: -263.76 - Epsilon: 0.01
# Episode 230/2000 - Score: -413.14 - Average Score: -268.99 - Epsilon: 0.01
# Episode 240/2000 - Score: -285.50 - Average Score: -262.63 - Epsilon: 0.01
# Episode 250/2000 - Score: -365.15 - Average Score: -266.30 - Epsilon: 0.01
# Episode 260/2000 - Score: -233.98 - Average Score: -257.76 - Epsilon: 0.01
# Episode 270/2000 - Score: -485.54 - Average Score: -254.85 - Epsilon: 0.01
# Episode 280/2000 - Score: -43.37 - Average Score: -250.89 - Epsilon: 0.01
# Episode 290/2000 - Score: -296.59 - Average Score: -240.75 - Epsilon: 0.01
# Episode 300/2000 - Score: -428.39 - Average Score: -241.92 - Epsilon: 0.01
# Episode 310/2000 - Score: -389.82 - Average Score: -235.36 - Epsilon: 0.01
# Episode 320/2000 - Score: -289.20 - Average Score: -236.15 - Epsilon: 0.01
# Episode 330/2000 - Score: -113.56 - Average Score: -228.10 - Epsilon: 0.01
# Episode 340/2000 - Score: -192.37 - Average Score: -222.96 - Epsilon: 0.01
# Episode 350/2000 - Score: -90.21 - Average Score: -218.04 - Epsilon: 0.01
# Episode 360/2000 - Score: -57.55 - Average Score: -218.71 - Epsilon: 0.01
# Episode 370/2000 - Score: -183.11 - Average Score: -214.08 - Epsilon: 0.01
# Episode 380/2000 - Score: -152.70 - Average Score: -208.12 - Epsilon: 0.01
# Episode 390/2000 - Score: -137.38 - Average Score: -199.05 - Epsilon: 0.01
# Episode 400/2000 - Score: -160.25 - Average Score: -194.53 - Epsilon: 0.01
# Episode 410/2000 - Score: -192.71 - Average Score: -192.15 - Epsilon: 0.01
# Episode 420/2000 - Score: -428.08 - Average Score: -198.47 - Epsilon: 0.01
# Episode 430/2000 - Score: -184.55 - Average Score: -193.19 - Epsilon: 0.01
# Episode 440/2000 - Score: -115.53 - Average Score: -191.38 - Epsilon: 0.01
# Episode 450/2000 - Score: -245.14 - Average Score: -191.39 - Epsilon: 0.01
# Episode 460/2000 - Score: -130.76 - Average Score: -191.15 - Epsilon: 0.01
# Episode 470/2000 - Score: -83.96 - Average Score: -189.47 - Epsilon: 0.01
# Episode 480/2000 - Score: -114.24 - Average Score: -185.43 - Epsilon: 0.01
# Episode 490/2000 - Score: -166.54 - Average Score: -184.96 - Epsilon: 0.01
# Episode 500/2000 - Score: -73.95 - Average Score: -181.67 - Epsilon: 0.01
# Episode 510/2000 - Score: -365.15 - Average Score: -176.11 - Epsilon: 0.01
# Episode 520/2000 - Score: -144.30 - Average Score: -165.60 - Epsilon: 0.01
# Episode 530/2000 - Score: 14.89 - Average Score: -157.19 - Epsilon: 0.01
# Episode 540/2000 - Score: -22.64 - Average Score: -150.17 - Epsilon: 0.01
# Episode 550/2000 - Score: 14.33 - Average Score: -141.14 - Epsilon: 0.01
# Episode 560/2000 - Score: -322.12 - Average Score: -145.63 - Epsilon: 0.01
# Episode 570/2000 - Score: -176.05 - Average Score: -147.15 - Epsilon: 0.01
# Episode 580/2000 - Score: -223.44 - Average Score: -143.98 - Epsilon: 0.01
# Episode 590/2000 - Score: 39.30 - Average Score: -152.59 - Epsilon: 0.01
# Episode 600/2000 - Score: -185.68 - Average Score: -148.91 - Epsilon: 0.01
# Episode 610/2000 - Score: -136.22 - Average Score: -159.39 - Epsilon: 0.01
# Episode 620/2000 - Score: -21.11 - Average Score: -156.78 - Epsilon: 0.01
# Episode 630/2000 - Score: -165.47 - Average Score: -157.18 - Epsilon: 0.01
# Episode 640/2000 - Score: -165.20 - Average Score: -163.85 - Epsilon: 0.01
# Episode 650/2000 - Score: -102.41 - Average Score: -163.30 - Epsilon: 0.01
# Episode 660/2000 - Score: -219.06 - Average Score: -163.13 - Epsilon: 0.01
# Episode 670/2000 - Score: -75.02 - Average Score: -156.01 - Epsilon: 0.01
# Episode 680/2000 - Score: -179.33 - Average Score: -158.95 - Epsilon: 0.01
# Episode 690/2000 - Score: -11.55 - Average Score: -152.56 - Epsilon: 0.01
# Episode 700/2000 - Score: -247.99 - Average Score: -160.05 - Epsilon: 0.01
# Episode 710/2000 - Score: -28.43 - Average Score: -158.20 - Epsilon: 0.01
# Episode 720/2000 - Score: -407.85 - Average Score: -161.94 - Epsilon: 0.01
# Episode 730/2000 - Score: -183.95 - Average Score: -165.29 - Epsilon: 0.01
# Episode 740/2000 - Score: -285.69 - Average Score: -172.50 - Epsilon: 0.01
# Episode 750/2000 - Score: -213.57 - Average Score: -178.41 - Epsilon: 0.01
# Episode 760/2000 - Score: -120.34 - Average Score: -173.27 - Epsilon: 0.01
# Episode 770/2000 - Score: -204.17 - Average Score: -174.40 - Epsilon: 0.01
# Episode 780/2000 - Score: -168.37 - Average Score: -176.36 - Epsilon: 0.01
# Episode 790/2000 - Score: -124.51 - Average Score: -176.51 - Epsilon: 0.01
# Episode 800/2000 - Score: -187.66 - Average Score: -176.05 - Epsilon: 0.01
# Episode 810/2000 - Score: -53.83 - Average Score: -167.83 - Epsilon: 0.01
# Episode 820/2000 - Score: -166.74 - Average Score: -167.92 - Epsilon: 0.01
# Episode 830/2000 - Score: -108.60 - Average Score: -165.60 - Epsilon: 0.01
# Episode 840/2000 - Score: -58.87 - Average Score: -157.03 - Epsilon: 0.01
# Episode 850/2000 - Score: -82.90 - Average Score: -153.34 - Epsilon: 0.01
# Episode 860/2000 - Score: -123.28 - Average Score: -152.60 - Epsilon: 0.01
# Episode 870/2000 - Score: -229.27 - Average Score: -156.10 - Epsilon: 0.01
# Episode 880/2000 - Score: -332.96 - Average Score: -157.40 - Epsilon: 0.01
# Episode 890/2000 - Score: -122.08 - Average Score: -154.01 - Epsilon: 0.01
# Episode 900/2000 - Score: -116.11 - Average Score: -151.05 - Epsilon: 0.01
# Episode 910/2000 - Score: -158.04 - Average Score: -150.19 - Epsilon: 0.01
# Episode 920/2000 - Score: -136.33 - Average Score: -146.87 - Epsilon: 0.01
# Episode 930/2000 - Score: -93.09 - Average Score: -146.04 - Epsilon: 0.01
# Episode 940/2000 - Score: -79.27 - Average Score: -149.30 - Epsilon: 0.01
# Episode 950/2000 - Score: -74.49 - Average Score: -146.30 - Epsilon: 0.01
# Episode 960/2000 - Score: -95.59 - Average Score: -144.09 - Epsilon: 0.01
# Episode 970/2000 - Score: -137.93 - Average Score: -137.62 - Epsilon: 0.01
# Episode 980/2000 - Score: -129.80 - Average Score: -132.35 - Epsilon: 0.01
# Episode 990/2000 - Score: -78.86 - Average Score: -127.58 - Epsilon: 0.01
# Episode 1000/2000 - Score: -107.81 - Average Score: -128.45 - Epsilon: 0.01
# Episode 1010/2000 - Score: -96.59 - Average Score: -126.29 - Epsilon: 0.01
# Episode 1020/2000 - Score: -69.11 - Average Score: -127.56 - Epsilon: 0.01
# Episode 1030/2000 - Score: -76.79 - Average Score: -120.36 - Epsilon: 0.01
# Episode 1040/2000 - Score: -127.36 - Average Score: -115.92 - Epsilon: 0.01
# Episode 1050/2000 - Score: -216.77 - Average Score: -118.68 - Epsilon: 0.01
# Episode 1060/2000 - Score: -82.25 - Average Score: -118.15 - Epsilon: 0.01
# Episode 1070/2000 - Score: -211.69 - Average Score: -119.82 - Epsilon: 0.01
# Episode 1080/2000 - Score: -154.10 - Average Score: -119.68 - Epsilon: 0.01
# Episode 1090/2000 - Score: -134.73 - Average Score: -120.40 - Epsilon: 0.01
# Episode 1100/2000 - Score: -143.75 - Average Score: -119.66 - Epsilon: 0.01
# Episode 1110/2000 - Score: -440.38 - Average Score: -126.27 - Epsilon: 0.01
# Episode 1120/2000 - Score: -99.24 - Average Score: -125.65 - Epsilon: 0.01
# Episode 1130/2000 - Score: -162.68 - Average Score: -131.13 - Epsilon: 0.01
# Episode 1140/2000 - Score: -194.51 - Average Score: -131.67 - Epsilon: 0.01
# Episode 1150/2000 - Score: -182.15 - Average Score: -132.21 - Epsilon: 0.01
# Episode 1160/2000 - Score: -122.33 - Average Score: -135.96 - Epsilon: 0.01
# Episode 1170/2000 - Score: -174.70 - Average Score: -143.30 - Epsilon: 0.01
# Episode 1180/2000 - Score: -140.70 - Average Score: -146.78 - Epsilon: 0.01
# Episode 1190/2000 - Score: -122.27 - Average Score: -149.33 - Epsilon: 0.01
# Episode 1200/2000 - Score: -134.73 - Average Score: -154.26 - Epsilon: 0.01
# Episode 1210/2000 - Score: -129.56 - Average Score: -154.29 - Epsilon: 0.01
# Episode 1220/2000 - Score: -479.21 - Average Score: -156.03 - Epsilon: 0.01
# Episode 1230/2000 - Score: -151.83 - Average Score: -156.65 - Epsilon: 0.01
# Episode 1240/2000 - Score: -104.63 - Average Score: -154.67 - Epsilon: 0.01
# Episode 1250/2000 - Score: -68.89 - Average Score: -155.00 - Epsilon: 0.01
# Episode 1260/2000 - Score: -95.89 - Average Score: -149.37 - Epsilon: 0.01
# Episode 1270/2000 - Score: -96.42 - Average Score: -145.28 - Epsilon: 0.01
# Episode 1280/2000 - Score: -137.55 - Average Score: -140.49 - Epsilon: 0.01
# Episode 1290/2000 - Score: -110.72 - Average Score: -132.52 - Epsilon: 0.01
# Episode 1300/2000 - Score: -48.65 - Average Score: -127.55 - Epsilon: 0.01
# Episode 1310/2000 - Score: -101.45 - Average Score: -122.01 - Epsilon: 0.01
# Episode 1320/2000 - Score: -98.98 - Average Score: -119.07 - Epsilon: 0.01
# Episode 1330/2000 - Score: -151.81 - Average Score: -112.04 - Epsilon: 0.01
# Episode 1340/2000 - Score: -112.64 - Average Score: -112.20 - Epsilon: 0.01
# Episode 1350/2000 - Score: -90.26 - Average Score: -106.69 - Epsilon: 0.01
# Episode 1360/2000 - Score: -171.25 - Average Score: -108.69 - Epsilon: 0.01
# Episode 1370/2000 - Score: -89.96 - Average Score: -107.58 - Epsilon: 0.01
# Episode 1380/2000 - Score: -150.84 - Average Score: -108.48 - Epsilon: 0.01
# Episode 1390/2000 - Score: -87.74 - Average Score: -109.84 - Epsilon: 0.01
# Episode 1400/2000 - Score: -123.04 - Average Score: -105.24 - Epsilon: 0.01
# Episode 1410/2000 - Score: -61.13 - Average Score: -107.81 - Epsilon: 0.01
# Episode 1420/2000 - Score: 24.65 - Average Score: -109.66 - Epsilon: 0.01
# Episode 1430/2000 - Score: -65.30 - Average Score: -110.72 - Epsilon: 0.01
# Episode 1440/2000 - Score: -83.17 - Average Score: -110.98 - Epsilon: 0.01
# Episode 1450/2000 - Score: -111.79 - Average Score: -115.72 - Epsilon: 0.01
# Episode 1460/2000 - Score: -123.05 - Average Score: -116.30 - Epsilon: 0.01
# Episode 1470/2000 - Score: -111.60 - Average Score: -113.24 - Epsilon: 0.01
# Episode 1480/2000 - Score: -151.41 - Average Score: -119.11 - Epsilon: 0.01
# Episode 1490/2000 - Score: -103.54 - Average Score: -129.05 - Epsilon: 0.01
# Episode 1500/2000 - Score: -172.89 - Average Score: -142.19 - Epsilon: 0.01
# Episode 1510/2000 - Score: -218.51 - Average Score: -145.19 - Epsilon: 0.01
# Episode 1520/2000 - Score: -196.17 - Average Score: -151.89 - Epsilon: 0.01
# Episode 1530/2000 - Score: -15.55 - Average Score: -158.70 - Epsilon: 0.01
# Episode 1540/2000 - Score: -190.75 - Average Score: -165.75 - Epsilon: 0.01
# Episode 1550/2000 - Score: -182.84 - Average Score: -172.25 - Epsilon: 0.01
# Episode 1560/2000 - Score: -108.98 - Average Score: -176.23 - Epsilon: 0.01
# Episode 1570/2000 - Score: -207.98 - Average Score: -183.90 - Epsilon: 0.01
# Episode 1580/2000 - Score: -192.35 - Average Score: -185.04 - Epsilon: 0.01
# Episode 1590/2000 - Score: -130.57 - Average Score: -178.10 - Epsilon: 0.01
# Episode 1600/2000 - Score: -118.89 - Average Score: -170.28 - Epsilon: 0.01
# Episode 1610/2000 - Score: -154.07 - Average Score: -169.11 - Epsilon: 0.01
# Episode 1620/2000 - Score: -104.10 - Average Score: -158.44 - Epsilon: 0.01
# Episode 1630/2000 - Score: -146.88 - Average Score: -150.86 - Epsilon: 0.01
# Episode 1640/2000 - Score: -36.34 - Average Score: -146.75 - Epsilon: 0.01
# Episode 1650/2000 - Score: -178.82 - Average Score: -135.43 - Epsilon: 0.01
# Episode 1660/2000 - Score: -67.03 - Average Score: -133.88 - Epsilon: 0.01
# Episode 1670/2000 - Score: -165.29 - Average Score: -130.02 - Epsilon: 0.01
# Episode 1680/2000 - Score: -145.50 - Average Score: -133.15 - Epsilon: 0.01
# Episode 1690/2000 - Score: -96.62 - Average Score: -141.66 - Epsilon: 0.01
# Episode 1700/2000 - Score: -93.50 - Average Score: -148.85 - Epsilon: 0.01
# Episode 1710/2000 - Score: -354.17 - Average Score: -160.95 - Epsilon: 0.01
# Episode 1720/2000 - Score: -198.06 - Average Score: -185.85 - Epsilon: 0.01
# Episode 1730/2000 - Score: -724.97 - Average Score: -206.73 - Epsilon: 0.01
# Episode 1740/2000 - Score: -445.63 - Average Score: -236.69 - Epsilon: 0.01
# Episode 1750/2000 - Score: -167.56 - Average Score: -262.10 - Epsilon: 0.01
# Episode 1760/2000 - Score: -147.25 - Average Score: -282.23 - Epsilon: 0.01
# Episode 1770/2000 - Score: -186.25 - Average Score: -308.93 - Epsilon: 0.01
# Episode 1780/2000 - Score: -247.81 - Average Score: -324.85 - Epsilon: 0.01
# Episode 1790/2000 - Score: -117.21 - Average Score: -341.94 - Epsilon: 0.01
# Episode 1800/2000 - Score: -451.85 - Average Score: -355.73 - Epsilon: 0.01
# Episode 1810/2000 - Score: 47.66 - Average Score: -372.76 - Epsilon: 0.01
# Episode 1820/2000 - Score: -111.10 - Average Score: -380.49 - Epsilon: 0.01
# Episode 1830/2000 - Score: -448.55 - Average Score: -400.76 - Epsilon: 0.01
# Episode 1840/2000 - Score: -159.67 - Average Score: -419.53 - Epsilon: 0.01
# Episode 1850/2000 - Score: -227.19 - Average Score: -433.62 - Epsilon: 0.01
# Episode 1860/2000 - Score: -424.98 - Average Score: -441.48 - Epsilon: 0.01
# Episode 1870/2000 - Score: -795.46 - Average Score: -443.70 - Epsilon: 0.01
# Episode 1880/2000 - Score: -325.65 - Average Score: -442.56 - Epsilon: 0.01
# Episode 1890/2000 - Score: -190.39 - Average Score: -424.87 - Epsilon: 0.01
# Episode 1900/2000 - Score: -175.93 - Average Score: -425.89 - Epsilon: 0.01
# Episode 1910/2000 - Score: -269.11 - Average Score: -405.23 - Epsilon: 0.01
# Episode 1920/2000 - Score: -224.14 - Average Score: -389.55 - Epsilon: 0.01
# Episode 1930/2000 - Score: -243.76 - Average Score: -366.21 - Epsilon: 0.01
# Episode 1940/2000 - Score: -189.36 - Average Score: -316.69 - Epsilon: 0.01
# Episode 1950/2000 - Score: -113.98 - Average Score: -291.08 - Epsilon: 0.01
# Episode 1960/2000 - Score: -350.84 - Average Score: -263.28 - Epsilon: 0.01
# Episode 1970/2000 - Score: -179.29 - Average Score: -239.79 - Epsilon: 0.01
# Episode 1980/2000 - Score: -146.33 - Average Score: -216.13 - Epsilon: 0.01
# Episode 1990/2000 - Score: -127.34 - Average Score: -203.50 - Epsilon: 0.01

# %% [markdown]
# ### Visualization

# %%
# For visualization
from gym.wrappers.monitoring import video_recorder
from IPython.display import HTML
from IPython import display
import glob
import base64, io, os

os.environ['SDL_VIDEODRIVER']='dummy'

# %%
import gym
import matplotlib.pyplot as plt
from IPython.display import clear_output

def visualize_model(agent, render_mode, max_steps=10000, seed=42):
    # Initialize the environment with the given render mode
    env = gym.make("LunarLander-v2", render_mode=render_mode)
    
    # Set the seed for reproducibility
    state, info = env.reset(seed=seed)
    
    for episode in range(1):

        terminated = False
        truncated = False
        steps = 0
        
        while not (terminated or truncated) and steps < max_steps:
            # Choose an action using the agent
            action = agent.choose_action(state)
            
            # Take the action and get the next state and reward
            new_state, reward, terminated, truncated, info = env.step(action)
            state = new_state
            
            # Render the environment if in rgb_array mode for animation
            if render_mode == 'rgb_array':
                clear_output(wait=True)
                plt.imshow(env.render())
                plt.axis('off')
                plt.show()
                
            steps += 1
        
        # Reset the environment for the next episode
        state, info = env.reset()
    
    # Close the environment
    env.close()

visualize_model(agent, render_mode='rgb_array')
