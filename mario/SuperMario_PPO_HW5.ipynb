# %% [markdown]
# #Task
#
# We will train a PPO agent which learns to play the classic super mario game.
#
# You can use the stable baselines implementation of PPO or right your own version.
#
# For the env, we will use gym_super_mario_bros. Read more about it [Here](https://github.com/Kautenja/gym-super-mario-bros/)
#
# Note that the stable-baselines3 implementations expect a gymnasium environment and not a gym environment (gymnasium is the upgraded form of gym. gym is depreciated but we can still find a lot of environments made in it.)
#
# Fortunately, gymnasium has a way to resolve that issue and convert a gym env to a gymnasium env. We do need to install a compatible version of gym though.

# %%
# %pip install swig
# %pip install stable-baselines3 gymnasium[all] gym_super_mario_bros nes_py gym==0.10.9  # might need a restart of the session.
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: swig in /Users/dkjulhin/Library/Python/3.9/lib/python/site-packages (4.2.1)
# WARNING: You are using pip version 21.2.4; however, version 24.1.2 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# zsh:1: no matches found: gymnasium[all]
# Note: you may need to restart the kernel to use updated packages.

# %%
def frames_to_video(frames, fps=24):
    fig = plt.figure(figsize=(frames[0].shape[1] / 100, frames[0].shape[0] / 100), dpi=100)
    ax = plt.axes()
    ax.set_axis_off()

    if len(frames[0].shape) == 2:  # Grayscale image
        im = ax.imshow(frames[0], cmap='gray')
    else:  # Color image
        im = ax.imshow(frames[0])

    def init():
        if len(frames[0].shape) == 2:
            im.set_data(frames[0], cmap='gray')
        else:
            im.set_data(frames[0])
        return im,

    def update(frame):
        if len(frames[frame].shape) == 2:
            im.set_data(frames[frame], cmap='gray')
        else:
            im.set_data(frames[frame])
        return im,

    interval = 1000 / fps
    anim = FuncAnimation(fig, update, frames=len(frames), init_func=init, blit=True, interval=interval)
    plt.close()
    return HTML(anim.to_html5_video())

# %% [markdown]
# ## Making the environment
#
# On top of making the gym requirement, we will make a vectorized environment (provided by stable baselines 3)
#
# This introduces training over multiple environments simultaneously, making the traning faster. We will use DummyVecEnv which doesn't actually use subprocesses but if we were working with a complex environment with higher compute time, we could also use SubProcessVecEnv
#
# Think about what wrappers you can use to make the job easier. You can also make the action-space simpler. Read more about it in the env page referenced above.

# %% [markdown]
# Use `'SuperMarioBros-v0'` version of environment

# %%
# code here

# Import necessary libraries
import gym
from stable_baselines3 import PPO
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.results_plotter import load_results, ts2xy
from stable_baselines3.common.env_util import make_vec_env
import imageio
import numpy as np
import matplotlib.pyplot as plt
import os
import gym_super_mario_bros
from nes_py.wrappers import JoypadSpace
from gym_super_mario_bros.actions import SIMPLE_MOVEMENT
from stable_baselines3.common.env_util import make_atari_env
from stable_baselines3.common.vec_env import VecFrameStack

# Create a folder to save logs
log_dir = "tmp/"
os.makedirs(log_dir, exist_ok=True)

# Create the Super Mario Bros environment and wrap it in a Monitor wrapper
env = gym_super_mario_bros.make('SuperMarioBros-v0')
env = JoypadSpace(env, SIMPLE_MOVEMENT)
env = Monitor(env, log_dir)

# Stack frames for better temporal representation
env = VecFrameStack(make_vec_env(lambda: env, n_envs=1), n_stack=4)

# Set up the hyperparameters
ppo_hyperparams = {
    'learning_rate': 2.5e-4,
    'n_steps': 128,
    'batch_size': 256,
    'n_epochs': 4,
    'gamma': 0.99,
    'gae_lambda': 0.95,
    'clip_range': 0.1,
    'ent_coef': 0.01,
    'vf_coef': 0.5,
    'max_grad_norm': 0.5,
    'policy_kwargs': dict(net_arch=[dict(pi=[256, 256], vf=[256, 256])])
}

# Initialize the PPO model with the environment and custom hyperparameters
model = PPO("CnnPolicy", env, verbose=1, **ppo_hyperparams)

# Train the model
model.learn(total_timesteps=1000000, log_interval=10)

# Save the trained model
model.save("ppo_mario")

# Function to plot training progress
def plot_results(log_folder):
    x, y = ts2xy(load_results(log_folder), 'timesteps')
    plt.figure(figsize=(10, 5))
    plt.plot(x, y)
    plt.xlabel('Timesteps')
    plt.ylabel('Rewards')
    plt.title('Training Progress')
    plt.show()

# Plot the training progress
plot_results(log_dir)

# Delete the model to demonstrate loading
del model

# Load the saved model
model = PPO.load("ppo_mario")

# Reset the environment
obs = env.reset()

# Create a list to store frames
frames = []

# Run the model in the environment
for _ in range(1000):
    action, _states = model.predict(obs, deterministic=True)
    obs, reward, done, info = env.step(action)
    
    # Capture the current frame
    frame = env.render(mode='rgb_array')
    frames.append(frame)
    
    if done:
        obs = env.reset()

# Save frames as a video
video_filename = 'mario_ppo.mp4'
imageio.mimsave(video_filename, [np.array(frame) for frame in frames], fps=30)
# Out:
# Using cpu device
# Wrapping the env in a VecTransposeImage.
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 14           |
# |    iterations           | 10           |
# |    time_elapsed         | 90           |
# |    total_timesteps      | 1280         |
# | train/                  |              |
# |    approx_kl            | 0.0007551359 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.92        |
# |    explained_variance   | 0.00158      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.123        |
# |    n_updates            | 36           |
# |    policy_gradient_loss | 4.69e-05     |
# |    value_loss           | 1.01         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 20          |
# |    time_elapsed         | 185         |
# |    total_timesteps      | 2560        |
# | train/                  |             |
# |    approx_kl            | 0.003201555 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.7        |
# |    explained_variance   | -1.19e-06   |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0201      |
# |    n_updates            | 76          |
# |    policy_gradient_loss | -0.00626    |
# |    value_loss           | 0.0921      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 13           |
# |    iterations           | 30           |
# |    time_elapsed         | 280          |
# |    total_timesteps      | 3840         |
# | train/                  |              |
# |    approx_kl            | 0.0036934572 |
# |    clip_fraction        | 0.0234       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.67        |
# |    explained_variance   | 2.56e-06     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0132       |
# |    n_updates            | 116          |
# |    policy_gradient_loss | -0.00543     |
# |    value_loss           | 0.0841       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 13           |
# |    iterations           | 40           |
# |    time_elapsed         | 379          |
# |    total_timesteps      | 5120         |
# | train/                  |              |
# |    approx_kl            | 0.0024508121 |
# |    clip_fraction        | 0.0859       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.78        |
# |    explained_variance   | -1.79e-06    |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0511       |
# |    n_updates            | 156          |
# |    policy_gradient_loss | -0.0038      |
# |    value_loss           | 0.155        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 50          |
# |    time_elapsed         | 477         |
# |    total_timesteps      | 6400        |
# | train/                  |             |
# |    approx_kl            | 0.006772221 |
# |    clip_fraction        | 0.205       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.75       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0164      |
# |    n_updates            | 196         |
# |    policy_gradient_loss | -0.0069     |
# |    value_loss           | 0.0842      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 60          |
# |    time_elapsed         | 575         |
# |    total_timesteps      | 7680        |
# | train/                  |             |
# |    approx_kl            | 0.001579598 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.71       |
# |    explained_variance   | 1.79e-07    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0197      |
# |    n_updates            | 236         |
# |    policy_gradient_loss | -0.002      |
# |    value_loss           | 0.0842      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 70          |
# |    time_elapsed         | 674         |
# |    total_timesteps      | 8960        |
# | train/                  |             |
# |    approx_kl            | 0.002486383 |
# |    clip_fraction        | 0.0312      |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.58       |
# |    explained_variance   | 7.08e-05    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.116       |
# |    n_updates            | 276         |
# |    policy_gradient_loss | -0.00171    |
# |    value_loss           | 0.354       |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+04         |
# |    ep_rew_mean          | 1.33e+03      |
# | time/                   |               |
# |    fps                  | 13            |
# |    iterations           | 80            |
# |    time_elapsed         | 774           |
# |    total_timesteps      | 10240         |
# | train/                  |               |
# |    approx_kl            | 0.00035931217 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.5          |
# |    explained_variance   | 1.7e-05       |
# |    learning_rate        | 0.00025       |
# |    loss                 | 300           |
# |    n_updates            | 316           |
# |    policy_gradient_loss | -0.00111      |
# |    value_loss           | 618           |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+04       |
# |    ep_rew_mean          | 1.33e+03    |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 90          |
# |    time_elapsed         | 874         |
# |    total_timesteps      | 11520       |
# | train/                  |             |
# |    approx_kl            | 0.004090614 |
# |    clip_fraction        | 0.0254      |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.79       |
# |    explained_variance   | -4.77e-07   |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0549      |
# |    n_updates            | 356         |
# |    policy_gradient_loss | -0.000539   |
# |    value_loss           | 0.183       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+04        |
# |    ep_rew_mean          | 1.33e+03     |
# | time/                   |              |
# |    fps                  | 13           |
# |    iterations           | 100          |
# |    time_elapsed         | 974          |
# |    total_timesteps      | 12800        |
# | train/                  |              |
# |    approx_kl            | 0.0012254734 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.74        |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 326          |
# |    n_updates            | 396          |
# |    policy_gradient_loss | 0.001        |
# |    value_loss           | 655          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+04        |
# |    ep_rew_mean          | 1.33e+03     |
# | time/                   |              |
# |    fps                  | 13           |
# |    iterations           | 110          |
# |    time_elapsed         | 1075         |
# |    total_timesteps      | 14080        |
# | train/                  |              |
# |    approx_kl            | 0.0073595536 |
# |    clip_fraction        | 0.113        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.59        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0166       |
# |    n_updates            | 436          |
# |    policy_gradient_loss | -0.0069      |
# |    value_loss           | 0.0846       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+04        |
# |    ep_rew_mean          | 1.33e+03     |
# | time/                   |              |
# |    fps                  | 13           |
# |    iterations           | 120          |
# |    time_elapsed         | 1175         |
# |    total_timesteps      | 15360        |
# | train/                  |              |
# |    approx_kl            | 0.0042466116 |
# |    clip_fraction        | 0.0547       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0242       |
# |    n_updates            | 476          |
# |    policy_gradient_loss | -0.00244     |
# |    value_loss           | 0.0846       |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 7.97e+03      |
# |    ep_rew_mean          | 1.27e+03      |
# | time/                   |               |
# |    fps                  | 13            |
# |    iterations           | 130           |
# |    time_elapsed         | 1276          |
# |    total_timesteps      | 16640         |
# | train/                  |               |
# |    approx_kl            | 2.3894943e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.43         |
# |    explained_variance   | -8.34e-07     |
# |    learning_rate        | 0.00025       |
# |    loss                 | 73.1          |
# |    n_updates            | 516           |
# |    policy_gradient_loss | -0.00065      |
# |    value_loss           | 151           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.97e+03     |
# |    ep_rew_mean          | 1.27e+03     |
# | time/                   |              |
# |    fps                  | 13           |
# |    iterations           | 140          |
# |    time_elapsed         | 1377         |
# |    total_timesteps      | 17920        |
# | train/                  |              |
# |    approx_kl            | 0.0012879842 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | -3.1e-06     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0461       |
# |    n_updates            | 556          |
# |    policy_gradient_loss | -0.00324     |
# |    value_loss           | 0.22         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.97e+03     |
# |    ep_rew_mean          | 1.27e+03     |
# | time/                   |              |
# |    fps                  | 12           |
# |    iterations           | 150          |
# |    time_elapsed         | 1477         |
# |    total_timesteps      | 19200        |
# | train/                  |              |
# |    approx_kl            | 0.0027097329 |
# |    clip_fraction        | 0.0684       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.19        |
# |    explained_variance   | 1.06e-05     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 196          |
# |    n_updates            | 596          |
# |    policy_gradient_loss | -0.00375     |
# |    value_loss           | 397          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.97e+03     |
# |    ep_rew_mean          | 1.27e+03     |
# | time/                   |              |
# |    fps                  | 12           |
# |    iterations           | 160          |
# |    time_elapsed         | 1577         |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0003599953 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0681       |
# |    n_updates            | 636          |
# |    policy_gradient_loss | 0.000694     |
# |    value_loss           | 0.253        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 7.97e+03      |
# |    ep_rew_mean          | 1.27e+03      |
# | time/                   |               |
# |    fps                  | 12            |
# |    iterations           | 170           |
# |    time_elapsed         | 1676          |
# |    total_timesteps      | 21760         |
# | train/                  |               |
# |    approx_kl            | 0.00021874206 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.34         |
# |    explained_variance   | -2.38e-07     |
# |    learning_rate        | 0.00025       |
# |    loss                 | 0.0343        |
# |    n_updates            | 676           |
# |    policy_gradient_loss | 0.00199       |
# |    value_loss           | 0.0973        |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.97e+03     |
# |    ep_rew_mean          | 1.27e+03     |
# | time/                   |              |
# |    fps                  | 12           |
# |    iterations           | 180          |
# |    time_elapsed         | 1776         |
# |    total_timesteps      | 23040        |
# | train/                  |              |
# |    approx_kl            | 0.0024366118 |
# |    clip_fraction        | 0.0547       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.15        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0282       |
# |    n_updates            | 716          |
# |    policy_gradient_loss | -0.00399     |
# |    value_loss           | 0.0943       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.97e+03    |
# |    ep_rew_mean          | 1.27e+03    |
# | time/                   |             |
# |    fps                  | 12          |
# |    iterations           | 190         |
# |    time_elapsed         | 1876        |
# |    total_timesteps      | 24320       |
# | train/                  |             |
# |    approx_kl            | 0.001110856 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0322      |
# |    n_updates            | 756         |
# |    policy_gradient_loss | -0.000478   |
# |    value_loss           | 0.0942      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.97e+03     |
# |    ep_rew_mean          | 1.27e+03     |
# | time/                   |              |
# |    fps                  | 12           |
# |    iterations           | 200          |
# |    time_elapsed         | 1979         |
# |    total_timesteps      | 25600        |
# | train/                  |              |
# |    approx_kl            | 0.0026679793 |
# |    clip_fraction        | 0.0723       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.113        |
# |    n_updates            | 796          |
# |    policy_gradient_loss | 0.00136      |
# |    value_loss           | 0.251        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.97e+03     |
# |    ep_rew_mean          | 1.27e+03     |
# | time/                   |              |
# |    fps                  | 12           |
# |    iterations           | 210          |
# |    time_elapsed         | 2080         |
# |    total_timesteps      | 26880        |
# | train/                  |              |
# |    approx_kl            | 0.0018112818 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.112        |
# |    n_updates            | 836          |
# |    policy_gradient_loss | -0.00189     |
# |    value_loss           | 0.26         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 7.97e+03      |
# |    ep_rew_mean          | 1.27e+03      |
# | time/                   |               |
# |    fps                  | 12            |
# |    iterations           | 220           |
# |    time_elapsed         | 2177          |
# |    total_timesteps      | 28160         |
# | train/                  |               |
# |    approx_kl            | 4.3444335e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.3          |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.00025       |
# |    loss                 | 0.184         |
# |    n_updates            | 876           |
# |    policy_gradient_loss | -0.000438     |
# |    value_loss           | 0.36          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 9.78e+03      |
# |    ep_rew_mean          | 1.54e+03      |
# | time/                   |               |
# |    fps                  | 13            |
# |    iterations           | 230           |
# |    time_elapsed         | 2262          |
# |    total_timesteps      | 29440         |
# | train/                  |               |
# |    approx_kl            | 0.00050149765 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.48         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | 0.0767        |
# |    n_updates            | 916           |
# |    policy_gradient_loss | -0.0023       |
# |    value_loss           | 0.188         |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 9.78e+03     |
# |    ep_rew_mean          | 1.54e+03     |
# | time/                   |              |
# |    fps                  | 13           |
# |    iterations           | 240          |
# |    time_elapsed         | 2347         |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0013865912 |
# |    clip_fraction        | 0.0176       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.52        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0284       |
# |    n_updates            | 956          |
# |    policy_gradient_loss | -0.00042     |
# |    value_loss           | 0.0906       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 9.78e+03    |
# |    ep_rew_mean          | 1.54e+03    |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 250         |
# |    time_elapsed         | 2430        |
# |    total_timesteps      | 32000       |
# | train/                  |             |
# |    approx_kl            | 0.005777753 |
# |    clip_fraction        | 0.186       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.5        |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.029       |
# |    n_updates            | 996         |
# |    policy_gradient_loss | -0.00251    |
# |    value_loss           | 0.0896      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 9.78e+03     |
# |    ep_rew_mean          | 1.54e+03     |
# | time/                   |              |
# |    fps                  | 13           |
# |    iterations           | 260          |
# |    time_elapsed         | 2516         |
# |    total_timesteps      | 33280        |
# | train/                  |              |
# |    approx_kl            | 0.0019631116 |
# |    clip_fraction        | 0.00781      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0283       |
# |    n_updates            | 1036         |
# |    policy_gradient_loss | -0.00518     |
# |    value_loss           | 0.0986       |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 8.61e+03      |
# |    ep_rew_mean          | 1.67e+03      |
# | time/                   |               |
# |    fps                  | 13            |
# |    iterations           | 270           |
# |    time_elapsed         | 2600          |
# |    total_timesteps      | 34560         |
# | train/                  |               |
# |    approx_kl            | 7.5073913e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.47         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.00025       |
# |    loss                 | 0.18          |
# |    n_updates            | 1076          |
# |    policy_gradient_loss | -0.000102     |
# |    value_loss           | 0.323         |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 8.61e+03      |
# |    ep_rew_mean          | 1.67e+03      |
# | time/                   |               |
# |    fps                  | 13            |
# |    iterations           | 280           |
# |    time_elapsed         | 2685          |
# |    total_timesteps      | 35840         |
# | train/                  |               |
# |    approx_kl            | 0.00035102386 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.54         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.00025       |
# |    loss                 | 0.0644        |
# |    n_updates            | 1116          |
# |    policy_gradient_loss | 0.000882      |
# |    value_loss           | 0.228         |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.61e+03     |
# |    ep_rew_mean          | 1.67e+03     |
# | time/                   |              |
# |    fps                  | 13           |
# |    iterations           | 290          |
# |    time_elapsed         | 2769         |
# |    total_timesteps      | 37120        |
# | train/                  |              |
# |    approx_kl            | 0.0031460621 |
# |    clip_fraction        | 0.0254       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.68        |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.122        |
# |    n_updates            | 1156         |
# |    policy_gradient_loss | -0.00682     |
# |    value_loss           | 0.311        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.61e+03     |
# |    ep_rew_mean          | 1.67e+03     |
# | time/                   |              |
# |    fps                  | 13           |
# |    iterations           | 300          |
# |    time_elapsed         | 2853         |
# |    total_timesteps      | 38400        |
# | train/                  |              |
# |    approx_kl            | 0.0050877645 |
# |    clip_fraction        | 0.0645       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.45        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0392       |
# |    n_updates            | 1196         |
# |    policy_gradient_loss | -0.00213     |
# |    value_loss           | 0.111        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.92e+03     |
# |    ep_rew_mean          | 1.6e+03      |
# | time/                   |              |
# |    fps                  | 13           |
# |    iterations           | 310          |
# |    time_elapsed         | 2937         |
# |    total_timesteps      | 39680        |
# | train/                  |              |
# |    approx_kl            | 0.0002892036 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | 439          |
# |    n_updates            | 1236         |
# |    policy_gradient_loss | 0.00164      |
# |    value_loss           | 883          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 7.92e+03      |
# |    ep_rew_mean          | 1.6e+03       |
# | time/                   |               |
# |    fps                  | 13            |
# |    iterations           | 320           |
# |    time_elapsed         | 3022          |
# |    total_timesteps      | 40960         |
# | train/                  |               |
# |    approx_kl            | 0.00015353924 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.31         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | 0.0702        |
# |    n_updates            | 1276          |
# |    policy_gradient_loss | 0.000286      |
# |    value_loss           | 0.205         |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 7.92e+03      |
# |    ep_rew_mean          | 1.6e+03       |
# | time/                   |               |
# |    fps                  | 13            |
# |    iterations           | 330           |
# |    time_elapsed         | 3107          |
# |    total_timesteps      | 42240         |
# | train/                  |               |
# |    approx_kl            | 8.5122883e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.31         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | 706           |
# |    n_updates            | 1316          |
# |    policy_gradient_loss | 2.86e-05      |
# |    value_loss           | 1.42e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 7.06e+03      |
# |    ep_rew_mean          | 1.78e+03      |
# | time/                   |               |
# |    fps                  | 13            |
# |    iterations           | 340           |
# |    time_elapsed         | 3192          |
# |    total_timesteps      | 43520         |
# | train/                  |               |
# |    approx_kl            | 3.8789585e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.32         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | 936           |
# |    n_updates            | 1356          |
# |    policy_gradient_loss | -3.85e-05     |
# |    value_loss           | 1.88e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 6.23e+03      |
# |    ep_rew_mean          | 1.79e+03      |
# | time/                   |               |
# |    fps                  | 13            |
# |    iterations           | 350           |
# |    time_elapsed         | 3279          |
# |    total_timesteps      | 44800         |
# | train/                  |               |
# |    approx_kl            | 1.5158206e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.33         |
# |    explained_variance   | 1.79e-07      |
# |    learning_rate        | 0.00025       |
# |    loss                 | 604           |
# |    n_updates            | 1396          |
# |    policy_gradient_loss | 0.000476      |
# |    value_loss           | 1.21e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 5.69e+03      |
# |    ep_rew_mean          | 1.79e+03      |
# | time/                   |               |
# |    fps                  | 13            |
# |    iterations           | 360           |
# |    time_elapsed         | 3364          |
# |    total_timesteps      | 46080         |
# | train/                  |               |
# |    approx_kl            | 3.7085265e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.37         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.00025       |
# |    loss                 | 2.27          |
# |    n_updates            | 1436          |
# |    policy_gradient_loss | 3.14e-07      |
# |    value_loss           | 4.12          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 5.21e+03      |
# |    ep_rew_mean          | 1.76e+03      |
# | time/                   |               |
# |    fps                  | 13            |
# |    iterations           | 370           |
# |    time_elapsed         | 3449          |
# |    total_timesteps      | 47360         |
# | train/                  |               |
# |    approx_kl            | 1.1222437e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.38         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | 293           |
# |    n_updates            | 1476          |
# |    policy_gradient_loss | -4.01e-05     |
# |    value_loss           | 592           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 4.81e+03      |
# |    ep_rew_mean          | 1.73e+03      |
# | time/                   |               |
# |    fps                  | 13            |
# |    iterations           | 380           |
# |    time_elapsed         | 3533          |
# |    total_timesteps      | 48640         |
# | train/                  |               |
# |    approx_kl            | 4.9266964e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.39         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | 137           |
# |    n_updates            | 1516          |
# |    policy_gradient_loss | 8.44e-05      |
# |    value_loss           | 277           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 4.81e+03      |
# |    ep_rew_mean          | 1.73e+03      |
# | time/                   |               |
# |    fps                  | 13            |
# |    iterations           | 390           |
# |    time_elapsed         | 3616          |
# |    total_timesteps      | 49920         |
# | train/                  |               |
# |    approx_kl            | 1.3440847e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.39         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | 2.99          |
# |    n_updates            | 1556          |
# |    policy_gradient_loss | -0.000322     |
# |    value_loss           | 6.54          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4.81e+03     |
# |    ep_rew_mean          | 1.73e+03     |
# | time/                   |              |
# |    fps                  | 13           |
# |    iterations           | 400          |
# |    time_elapsed         | 3699         |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 9.276904e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | 553          |
# |    n_updates            | 1596         |
# |    policy_gradient_loss | -4.04e-06    |
# |    value_loss           | 1.11e+03     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 4.66e+03      |
# |    ep_rew_mean          | 1.72e+03      |
# | time/                   |               |
# |    fps                  | 13            |
# |    iterations           | 410           |
# |    time_elapsed         | 3780          |
# |    total_timesteps      | 52480         |
# | train/                  |               |
# |    approx_kl            | 1.1222437e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.38         |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.00025       |
# |    loss                 | 3.54          |
# |    n_updates            | 1636          |
# |    policy_gradient_loss | -7.78e-05     |
# |    value_loss           | 6.8           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 4.66e+03      |
# |    ep_rew_mean          | 1.72e+03      |
# | time/                   |               |
# |    fps                  | 13            |
# |    iterations           | 420           |
# |    time_elapsed         | 3863          |
# |    total_timesteps      | 53760         |
# | train/                  |               |
# |    approx_kl            | 4.2188913e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.39         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | 108           |
# |    n_updates            | 1676          |
# |    policy_gradient_loss | -5.67e-05     |
# |    value_loss           | 216           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 4.5e+03       |
# |    ep_rew_mean          | 1.75e+03      |
# | time/                   |               |
# |    fps                  | 13            |
# |    iterations           | 430           |
# |    time_elapsed         | 3944          |
# |    total_timesteps      | 55040         |
# | train/                  |               |
# |    approx_kl            | 3.6675483e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.38         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | 3.76          |
# |    n_updates            | 1716          |
# |    policy_gradient_loss | -0.000277     |
# |    value_loss           | 7.29          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 4.5e+03       |
# |    ep_rew_mean          | 1.75e+03      |
# | time/                   |               |
# |    fps                  | 13            |
# |    iterations           | 440           |
# |    time_elapsed         | 4025          |
# |    total_timesteps      | 56320         |
# | train/                  |               |
# |    approx_kl            | 6.2598847e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.36         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | 2.97          |
# |    n_updates            | 1756          |
# |    policy_gradient_loss | -0.000288     |
# |    value_loss           | 6.01          |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.5e+03     |
# |    ep_rew_mean          | 1.75e+03    |
# | time/                   |             |
# |    fps                  | 14          |
# |    iterations           | 450         |
# |    time_elapsed         | 4106        |
# |    total_timesteps      | 57600       |
# | train/                  |             |
# |    approx_kl            | 7.01705e-06 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.00025     |
# |    loss                 | 1.83        |
# |    n_updates            | 1796        |
# |    policy_gradient_loss | -0.000218   |
# |    value_loss           | 4.09        |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 4.49e+03      |
# |    ep_rew_mean          | 1.81e+03      |
# | time/                   |               |
# |    fps                  | 14            |
# |    iterations           | 460           |
# |    time_elapsed         | 4189          |
# |    total_timesteps      | 58880         |
# | train/                  |               |
# |    approx_kl            | 1.4994293e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.38         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | 202           |
# |    n_updates            | 1836          |
# |    policy_gradient_loss | 4.89e-06      |
# |    value_loss           | 406           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 4.25e+03      |
# |    ep_rew_mean          | 1.79e+03      |
# | time/                   |               |
# |    fps                  | 14            |
# |    iterations           | 470           |
# |    time_elapsed         | 4271          |
# |    total_timesteps      | 60160         |
# | train/                  |               |
# |    approx_kl            | 4.6612695e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.38         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | 579           |
# |    n_updates            | 1876          |
# |    policy_gradient_loss | -0.000102     |
# |    value_loss           | 1.16e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 4.05e+03      |
# |    ep_rew_mean          | 1.81e+03      |
# | time/                   |               |
# |    fps                  | 14            |
# |    iterations           | 480           |
# |    time_elapsed         | 4352          |
# |    total_timesteps      | 61440         |
# | train/                  |               |
# |    approx_kl            | 9.1828406e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.38         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | 4.16          |
# |    n_updates            | 1916          |
# |    policy_gradient_loss | -9.55e-05     |
# |    value_loss           | 8.08          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 4.05e+03      |
# |    ep_rew_mean          | 1.81e+03      |
# | time/                   |               |
# |    fps                  | 14            |
# |    iterations           | 490           |
# |    time_elapsed         | 4433          |
# |    total_timesteps      | 62720         |
# | train/                  |               |
# |    approx_kl            | 3.8789585e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.4          |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.00025       |
# |    loss                 | 613           |
# |    n_updates            | 1956          |
# |    policy_gradient_loss | 2.77e-05      |
# |    value_loss           | 1.23e+03      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.98e+03     |
# |    ep_rew_mean          | 1.85e+03     |
# | time/                   |              |
# |    fps                  | 14           |
# |    iterations           | 500          |
# |    time_elapsed         | 4514         |
# |    total_timesteps      | 64000        |
# | train/                  |              |
# |    approx_kl            | 8.055009e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 224          |
# |    n_updates            | 1996         |
# |    policy_gradient_loss | -0.000281    |
# |    value_loss           | 450          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.98e+03      |
# |    ep_rew_mean          | 1.85e+03      |
# | time/                   |               |
# |    fps                  | 14            |
# |    iterations           | 510           |
# |    time_elapsed         | 4596          |
# |    total_timesteps      | 65280         |
# | train/                  |               |
# |    approx_kl            | 9.5460564e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.38         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | 356           |
# |    n_updates            | 2036          |
# |    policy_gradient_loss | 3.49e-05      |
# |    value_loss           | 715           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.69e+03      |
# |    ep_rew_mean          | 1.84e+03      |
# | time/                   |               |
# |    fps                  | 14            |
# |    iterations           | 520           |
# |    time_elapsed         | 4678          |
# |    total_timesteps      | 66560         |
# | train/                  |               |
# |    approx_kl            | 1.1827797e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.39         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | 350           |
# |    n_updates            | 2076          |
# |    policy_gradient_loss | -1.61e-05     |
# |    value_loss           | 705           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.69e+03     |
# |    ep_rew_mean          | 1.84e+03     |
# | time/                   |              |
# |    fps                  | 14           |
# |    iterations           | 530          |
# |    time_elapsed         | 4760         |
# |    total_timesteps      | 67840        |
# | train/                  |              |
# |    approx_kl            | 7.414259e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | 6.68         |
# |    n_updates            | 2116         |
# |    policy_gradient_loss | -4.84e-05    |
# |    value_loss           | 13.8         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.69e+03     |
# |    ep_rew_mean          | 1.84e+03     |
# | time/                   |              |
# |    fps                  | 14           |
# |    iterations           | 540          |
# |    time_elapsed         | 4844         |
# |    total_timesteps      | 69120        |
# | train/                  |              |
# |    approx_kl            | 3.556721e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.4         |
# ...
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.26         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | 350           |
# |    n_updates            | 13796         |
# |    policy_gradient_loss | 0.00119       |
# |    value_loss           | 703           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.4e+03       |
# |    ep_rew_mean          | 1.95e+03      |
# | time/                   |               |
# |    fps                  | 14            |
# |    iterations           | 3460          |
# |    time_elapsed         | 30500         |
# |    total_timesteps      | 442880        |
# | train/                  |               |
# |    approx_kl            | 0.00025861012 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.22         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | 0.0326        |
# |    n_updates            | 13836         |
# |    policy_gradient_loss | 5.47e-05      |
# |    value_loss           | 0.0886        |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.4e+03       |
# |    ep_rew_mean          | 1.95e+03      |
# | time/                   |               |
# |    fps                  | 8             |
# |    iterations           | 3470          |
# |    time_elapsed         | 51360         |
# |    total_timesteps      | 444160        |
# | train/                  |               |
# |    approx_kl            | 0.00010372093 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.14         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | 34.8          |
# |    n_updates            | 13876         |
# |    policy_gradient_loss | -0.00187      |
# |    value_loss           | 70.3          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.42e+03      |
# |    ep_rew_mean          | 1.96e+03      |
# | time/                   |               |
# |    fps                  | 8             |
# |    iterations           | 3480          |
# |    time_elapsed         | 51455         |
# |    total_timesteps      | 445440        |
# | train/                  |               |
# |    approx_kl            | 0.00016364455 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.09         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | 101           |
# |    n_updates            | 13916         |
# |    policy_gradient_loss | -6.27e-05     |
# |    value_loss           | 204           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.42e+03      |
# |    ep_rew_mean          | 1.96e+03      |
# | time/                   |               |
# |    fps                  | 8             |
# |    iterations           | 3490          |
# |    time_elapsed         | 51529         |
# |    total_timesteps      | 446720        |
# | train/                  |               |
# |    approx_kl            | 5.1375944e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.06         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | 0.445         |
# |    n_updates            | 13956         |
# |    policy_gradient_loss | 0.000462      |
# |    value_loss           | 0.936         |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.44e+03      |
# |    ep_rew_mean          | 1.97e+03      |
# | time/                   |               |
# |    fps                  | 8             |
# |    iterations           | 3500          |
# |    time_elapsed         | 51604         |
# |    total_timesteps      | 448000        |
# | train/                  |               |
# |    approx_kl            | 3.8213097e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.11         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | 0.435         |
# |    n_updates            | 13996         |
# |    policy_gradient_loss | -0.000421     |
# |    value_loss           | 1.01          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.44e+03      |
# |    ep_rew_mean          | 1.97e+03      |
# | time/                   |               |
# |    fps                  | 8             |
# |    iterations           | 3510          |
# |    time_elapsed         | 51675         |
# |    total_timesteps      | 449280        |
# | train/                  |               |
# |    approx_kl            | 0.00058577815 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.13         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | 0.213         |
# |    n_updates            | 14036         |
# |    policy_gradient_loss | -0.00433      |
# |    value_loss           | 0.597         |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.47e+03     |
# |    ep_rew_mean          | 1.97e+03     |
# | time/                   |              |
# |    fps                  | 8            |
# |    iterations           | 3520         |
# |    time_elapsed         | 51748        |
# |    total_timesteps      | 450560       |
# | train/                  |              |
# |    approx_kl            | 6.802473e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.23        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | 438          |
# |    n_updates            | 14076        |
# |    policy_gradient_loss | 0.000524     |
# |    value_loss           | 879          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.47e+03     |
# |    ep_rew_mean          | 1.97e+03     |
# | time/                   |              |
# |    fps                  | 8            |
# |    iterations           | 3530         |
# |    time_elapsed         | 51822        |
# |    total_timesteps      | 451840       |
# | train/                  |              |
# |    approx_kl            | 4.581455e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.21        |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.15         |
# |    n_updates            | 14116        |
# |    policy_gradient_loss | -0.000491    |
# |    value_loss           | 0.354        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.47e+03      |
# |    ep_rew_mean          | 1.97e+03      |
# | time/                   |               |
# |    fps                  | 8             |
# |    iterations           | 3540          |
# |    time_elapsed         | 51893         |
# |    total_timesteps      | 453120        |
# | train/                  |               |
# |    approx_kl            | 1.9691885e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.23         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | 0.215         |
# |    n_updates            | 14156         |
# |    policy_gradient_loss | -0.000342     |
# |    value_loss           | 0.41          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.49e+03     |
# |    ep_rew_mean          | 1.98e+03     |
# | time/                   |              |
# |    fps                  | 8            |
# |    iterations           | 3550         |
# |    time_elapsed         | 51964        |
# |    total_timesteps      | 454400       |
# | train/                  |              |
# |    approx_kl            | 0.0002694521 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.23        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.183        |
# |    n_updates            | 14196        |
# |    policy_gradient_loss | -0.000258    |
# |    value_loss           | 0.434        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.49e+03      |
# |    ep_rew_mean          | 1.98e+03      |
# | time/                   |               |
# |    fps                  | 8             |
# |    iterations           | 3560          |
# |    time_elapsed         | 52035         |
# |    total_timesteps      | 455680        |
# | train/                  |               |
# |    approx_kl            | 0.00027284585 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.3          |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | 0.0363        |
# |    n_updates            | 14236         |
# |    policy_gradient_loss | -0.000548     |
# |    value_loss           | 0.129         |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.52e+03     |
# |    ep_rew_mean          | 1.98e+03     |
# | time/                   |              |
# |    fps                  | 8            |
# |    iterations           | 3570         |
# |    time_elapsed         | 52108        |
# |    total_timesteps      | 456960       |
# | train/                  |              |
# |    approx_kl            | 9.945128e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.03        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.00025      |
# |    loss                 | 25.5         |
# |    n_updates            | 14276        |
# |    policy_gradient_loss | -0.000121    |
# |    value_loss           | 51.3         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.52e+03      |
# |    ep_rew_mean          | 1.98e+03      |
# | time/                   |               |
# |    fps                  | 8             |
# |    iterations           | 3580          |
# |    time_elapsed         | 52183         |
# |    total_timesteps      | 458240        |
# | train/                  |               |
# |    approx_kl            | 1.9585714e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.1          |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | 30.5          |
# |    n_updates            | 14316         |
# |    policy_gradient_loss | -9.14e-05     |
# |    value_loss           | 61.5          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.53e+03      |
# |    ep_rew_mean          | 1.99e+03      |
# | time/                   |               |
# |    fps                  | 8             |
# |    iterations           | 3590          |
# |    time_elapsed         | 52261         |
# |    total_timesteps      | 459520        |
# | train/                  |               |
# |    approx_kl            | 0.00029666582 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.08         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | 224           |
# |    n_updates            | 14356         |
# |    policy_gradient_loss | 0.000368      |
# |    value_loss           | 450           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.53e+03      |
# |    ep_rew_mean          | 1.99e+03      |
# | time/                   |               |
# |    fps                  | 8             |
# |    iterations           | 3600          |
# |    time_elapsed         | 52337         |
# |    total_timesteps      | 460800        |
# | train/                  |               |
# |    approx_kl            | 3.9255247e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.05         |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.00025       |
# |    loss                 | 647           |
# |    n_updates            | 14396         |
# |    policy_gradient_loss | -4.06e-05     |
# |    value_loss           | 1.3e+03       |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.53e+03     |
# |    ep_rew_mean          | 2e+03        |
# | time/                   |              |
# |    fps                  | 8            |
# |    iterations           | 3610         |
# |    time_elapsed         | 52419        |
# |    total_timesteps      | 462080       |
# | train/                  |              |
# |    approx_kl            | 0.0001296727 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | 383          |
# |    n_updates            | 14436        |
# |    policy_gradient_loss | -0.000561    |
# |    value_loss           | 769          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.52e+03      |
# |    ep_rew_mean          | 1.99e+03      |
# | time/                   |               |
# |    fps                  | 8             |
# |    iterations           | 3620          |
# |    time_elapsed         | 52503         |
# |    total_timesteps      | 463360        |
# | train/                  |               |
# |    approx_kl            | 1.3131648e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.1          |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.00025       |
# |    loss                 | 712           |
# |    n_updates            | 14476         |
# |    policy_gradient_loss | -2.22e-05     |
# |    value_loss           | 1.43e+03      |
# -------------------------------------------

# %% [markdown]
# ## Creating and training the model

# %%
# code here

# %% [markdown]
# ## Visualizing the results

# %%
t_env = get_vec_env(render_mode="rgb_array")

state = t_env.reset()
frames = []

while True:
    action, _ = model.predict(state)
    state_next, r, done, info = t_env.step(action)
    state = state_next.copy()
    frames.append(t_env.render())
    if done:
        break
    if len(frames) > 5000:  # to limit the video length in case mario is stuck on untrained models. can be removed
        break

t_env.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 t_env = get_vec_env(render_mode="rgb_array")
#       3 state = t_env.reset()
#       4 frames = []
#
# NameError: name 'get_vec_env' is not defined

# %%
frames_to_video(frames, fps=60)
